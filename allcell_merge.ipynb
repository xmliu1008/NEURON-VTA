# %%
import seaborn as sns
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt

sc.settings.verbosity = 3
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# scanpy==1.10.1 anndata==0.10.7 umap==0.5.6 numpy==1.26.4 scipy==1.11.4 pandas==2.1.4 scikit-learn==1.2.2 statsmodels==0.14.0 igraph==0.11.5 pynndescent==0.5.12

# %%
vta1= sc.read_h5ad('./VTA_1/VTA_1_filter.h5ad')
vta2= sc.read_h5ad('./VTA_2/VTA_2_filter.h5ad')

# %%
vta1
# Out:
# AnnData object with n_obs × n_vars = 8799 × 23478
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'leiden_res_0.50', 'leiden_res_0.80', 'leiden_res_1.00', 'leiden_res_1.20', 'leiden_res_1.50', 'Neuron'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Neuron_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'log1p', 'neighbors', 'pca', 'predicted_doublet_colors', 'scrublet', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
vta2= sc.read_h5ad('./VTA_2/VTA_2_clustering_ann.h5ad')

# %%
vta2
# Out:
# AnnData object with n_obs × n_vars = 14230 × 24406
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'leiden_res_0.50', 'leiden_res_0.80', 'leiden_res_1.00', 'leiden_res_1.20', 'leiden_res_1.50', 'Neuron'
#     var: 'gene_ids', 'feature_types', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Neuron_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'log1p', 'neighbors', 'pca', 'predicted_doublet_colors', 'scrublet', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata = sc.AnnData.concatenate(vta1,vta2,batch_categories=('VTA_1','VTA_2'),batch_key='Sample')
adata.write_h5ad('./VTA_allcell_merge.h5ad')
# Out:
# /var/folders/r4/hfj1yx3s3bd93mtgxzfwcfyc0000gn/T/ipykernel_80056/1157260052.py:1: FutureWarning: Use anndata.concat instead of AnnData.concatenate, AnnData.concatenate is deprecated and will be removed in the future. See the tutorial for concat at: https://anndata.readthedocs.io/en/latest/concatenation.html
#   adata = sc.AnnData.concatenate(vta1,vta2,batch_categories=('VTA_1','VTA_2'),batch_key='Sample')

# %%
sc.pl.umap(
    adata,
    color="Sample",
    legend_fontsize=8
)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 23029 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'leiden_res_0.50', 'leiden_res_0.80', 'leiden_res_1.00', 'leiden_res_1.20', 'leiden_res_1.50', 'Neuron', 'Sample'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2'
#     uns: 'Sample_colors'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'counts'

# %%
sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5,flavor='seurat')
# Out:
# extracting highly variable genes
#     finished (0:00:00)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
sc.set_figure_params(color_map='RdBu_r')
sc.tl.pca(adata, svd_solver='arpack',use_highly_variable=True)
# Out:
# computing PCA
#     with n_comps=50
# /opt/anaconda3/lib/python3.11/site-packages/scanpy/preprocessing/_pca.py:374: FutureWarning: Argument `use_highly_variable` is deprecated, consider using the mask argument. Use_highly_variable=True can be called through mask_var="highly_variable". Use_highly_variable=False can be called through mask_var=None
#   warn(msg, FutureWarning)
#     finished (0:00:02)

# %%
sc.pp.neighbors(adata, n_neighbors=20, use_rep='X_pca')
sc.tl.umap(adata)
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:11)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:14)

# %%
sc.pl.highly_variable_genes(adata)
sc.pl.pca_variance_ratio(adata, n_pcs=50, log=True)

# %%
sc.pl.umap(
    adata,
    color=["Sample","Neuron"],
    legend_fontsize=8
)

# %%
adata.obs
# Out:
#                           n_genes  percent_mito  n_counts  doublet_score  \
# AAACCCAAGACTGTTC-1-VTA_1     2892           0.0    6381.0       0.093149
# AAACCCACATACCGTA-1-VTA_1     1016           0.0    1703.0       0.046853
# AAACCCAGTAACGCGA-1-VTA_1     4184           0.0   10386.0       0.089820
# AAACCCAGTCACTAGT-1-VTA_1     3622           0.0    8986.0       0.032307
# AAACGAAAGAGCATTA-1-VTA_1     1570           0.0    2479.0       0.013114
# ...                           ...           ...       ...            ...
# TTTGTTGGTTCCCACT-1-VTA_2     2275           0.0    4429.0       0.039110
# TTTGTTGGTTTAGACC-1-VTA_2     1140           0.0    1956.0       0.012198
# TTTGTTGTCACGAACT-1-VTA_2     4517           0.0   13127.0       0.111898
# TTTGTTGTCAGAGCAG-1-VTA_2     1271           0.0    2199.0       0.019010
# TTTGTTGTCCTCTTTC-1-VTA_2     1334           0.0    2163.0       0.035227
#
#                           predicted_doublet leiden_res_0.50 leiden_res_0.80  \
# AAACCCAAGACTGTTC-1-VTA_1              False               0               0
# AAACCCACATACCGTA-1-VTA_1              False               1               1
# AAACCCAGTAACGCGA-1-VTA_1              False               2               2
# AAACCCAGTCACTAGT-1-VTA_1              False               3               4
# AAACGAAAGAGCATTA-1-VTA_1              False               5               3
# ...                                     ...             ...             ...
# TTTGTTGGTTCCCACT-1-VTA_2              False               3               2
# TTTGTTGGTTTAGACC-1-VTA_2              False               2               1
# TTTGTTGTCACGAACT-1-VTA_2              False               7               9
# TTTGTTGTCAGAGCAG-1-VTA_2              False               5               4
# TTTGTTGTCCTCTTTC-1-VTA_2              False               3              17
#
#                          leiden_res_1.00 leiden_res_1.20 leiden_res_1.50  \
# AAACCCAAGACTGTTC-1-VTA_1               0               0               0
# AAACCCACATACCGTA-1-VTA_1               2               1               2
# AAACCCAGTAACGCGA-1-VTA_1               4               2               5
# AAACCCAGTCACTAGT-1-VTA_1               5               3               6
# AAACGAAAGAGCATTA-1-VTA_1               7               6               7
# ...                                  ...             ...             ...
# TTTGTTGGTTCCCACT-1-VTA_2              10               4               5
# TTTGTTGGTTTAGACC-1-VTA_2               1               1               1
# TTTGTTGTCACGAACT-1-VTA_2               4               9              19
# TTTGTTGTCAGAGCAG-1-VTA_2               8              15              18
# TTTGTTGTCCTCTTTC-1-VTA_2              10               4               5
#
#                               Neuron Sample
# AAACCCAAGACTGTTC-1-VTA_1      Neuron  VTA_1
# AAACCCACATACCGTA-1-VTA_1  Non-neuron  VTA_1
# AAACCCAGTAACGCGA-1-VTA_1      Neuron  VTA_1
# AAACCCAGTCACTAGT-1-VTA_1      Neuron  VTA_1
# AAACGAAAGAGCATTA-1-VTA_1      Neuron  VTA_1
# ...                              ...    ...
# TTTGTTGGTTCCCACT-1-VTA_2      Neuron  VTA_2
# TTTGTTGGTTTAGACC-1-VTA_2  Non-neuron  VTA_2
# TTTGTTGTCACGAACT-1-VTA_2      Neuron  VTA_2
# TTTGTTGTCAGAGCAG-1-VTA_2  Non-neuron  VTA_2
# TTTGTTGTCCTCTTTC-1-VTA_2      Neuron  VTA_2
#
# [23029 rows x 12 columns]

# %%
adata = adata[adata.obs['Neuron'].isin (['Neuron','Non-neuron']),:]

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 23014 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'leiden_res_0.50', 'leiden_res_0.80', 'leiden_res_1.00', 'leiden_res_1.20', 'leiden_res_1.50', 'Neuron', 'Sample'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Sample_colors', 'hvg', 'pca', 'Neuron_colors'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'

# %%
sc.pl.umap(
    adata,
    color=["Sample","Neuron"],
    legend_fontsize=8
)

# %%
adata.write('VTA_allcell_merge.h5ad')

# %%
sc.external.pp.harmony_integrate(adata, 'Sample', basis='X_pca', adjusted_basis='X_harmony')
# Out:
# 2024-05-20 11:36:13,213 - harmonypy - INFO - Computing initial centroids with sklearn.KMeans...
# 2024-05-20 11:36:15,410 - harmonypy - INFO - sklearn.KMeans initialization complete.
# 2024-05-20 11:36:15,466 - harmonypy - INFO - Iteration 1 of 10
# 2024-05-20 11:36:18,077 - harmonypy - INFO - Iteration 2 of 10
# 2024-05-20 11:36:20,673 - harmonypy - INFO - Iteration 3 of 10
# 2024-05-20 11:36:22,481 - harmonypy - INFO - Converged after 3 iterations
# /opt/anaconda3/lib/python3.11/site-packages/scanpy/external/pp/_harmony_integrate.py:97: ImplicitModificationWarning: Setting element `.obsm['X_harmony']` of view, initializing view as actual.
#   adata.obsm[adjusted_basis] = harmony_out.Z_corr.T

# %%
sc.pp.neighbors(adata, n_neighbors=20, use_rep='X_harmony')
# Out:
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:02)

# %%
sc.tl.umap(adata)
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:14)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 22748 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'Neuron', 'Sample', 'leiden_res_1.00', 'leiden_res_1.20', 'Neuron_merge', 'Class_new'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Neuron_colors', 'Neuron_merge_colors', 'Sample_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'dendrogram_leiden_res_1.20', 'dendrogram_leiden_res_1.50', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'neighbors', 'pca', 'umap', 'Class_new_colors', 'dendrogram_Class_new'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
del adata.uns['Sample_colors']
del adata.uns['Neuron_colors']

# %%
sc.pl.umap(
    adata,
    color=["Sample","Neuron"],palette=['#f27d25','#3e9160'],
    legend_fontsize=8,save='QC_merge.pdf'
)
# Out:
# WARNING: saving figure to file figures/umapQC_merge.pdf

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 22748 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'Neuron', 'Sample', 'leiden_res_1.00', 'leiden_res_1.20', 'Neuron_merge', 'Class_new'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Neuron_merge_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'dendrogram_leiden_res_1.20', 'dendrogram_leiden_res_1.50', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'neighbors', 'pca', 'umap', 'Class_new_colors', 'dendrogram_Class_new', 'Sample_colors', 'Neuron_colors'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata.write('VTA_allcell_merge_harmony.h5ad')

# %%
adata = sc.read_h5ad('VTA_allcell_merge_harmony.h5ad')

# %%
adata.obs
# Out:
#                           n_genes  percent_mito  n_counts  doublet_score  \
# AAACCCAAGACTGTTC-1-VTA_1     2892           0.0    6381.0       0.093149
# AAACCCACATACCGTA-1-VTA_1     1016           0.0    1703.0       0.046853
# AAACCCAGTAACGCGA-1-VTA_1     4184           0.0   10386.0       0.089820
# AAACCCAGTCACTAGT-1-VTA_1     3622           0.0    8986.0       0.032307
# AAACGAAAGAGCATTA-1-VTA_1     1570           0.0    2479.0       0.013114
# ...                           ...           ...       ...            ...
# TTTGTTGGTTCCCACT-1-VTA_2     2275           0.0    4429.0       0.039110
# TTTGTTGGTTTAGACC-1-VTA_2     1140           0.0    1956.0       0.012198
# TTTGTTGTCACGAACT-1-VTA_2     4517           0.0   13127.0       0.111898
# TTTGTTGTCAGAGCAG-1-VTA_2     1271           0.0    2199.0       0.019010
# TTTGTTGTCCTCTTTC-1-VTA_2     1334           0.0    2163.0       0.035227
#
#                           predicted_doublet      Neuron Sample  \
# AAACCCAAGACTGTTC-1-VTA_1              False      Neuron  VTA_1
# AAACCCACATACCGTA-1-VTA_1              False  Non-neuron  VTA_1
# AAACCCAGTAACGCGA-1-VTA_1              False      Neuron  VTA_1
# AAACCCAGTCACTAGT-1-VTA_1              False      Neuron  VTA_1
# AAACGAAAGAGCATTA-1-VTA_1              False      Neuron  VTA_1
# ...                                     ...         ...    ...
# TTTGTTGGTTCCCACT-1-VTA_2              False      Neuron  VTA_2
# TTTGTTGGTTTAGACC-1-VTA_2              False  Non-neuron  VTA_2
# TTTGTTGTCACGAACT-1-VTA_2              False      Neuron  VTA_2
# TTTGTTGTCAGAGCAG-1-VTA_2              False  Non-neuron  VTA_2
# TTTGTTGTCCTCTTTC-1-VTA_2              False      Neuron  VTA_2
#
#                          leiden_res_0.50 leiden_res_0.80 leiden_res_1.00  \
# AAACCCAAGACTGTTC-1-VTA_1               0               0               0
# AAACCCACATACCGTA-1-VTA_1               2               1               1
# AAACCCAGTAACGCGA-1-VTA_1               3               3               3
# AAACCCAGTCACTAGT-1-VTA_1               1               4               4
# AAACGAAAGAGCATTA-1-VTA_1               4               5               6
# ...                                  ...             ...             ...
# TTTGTTGGTTCCCACT-1-VTA_2               1               4               4
# TTTGTTGGTTTAGACC-1-VTA_2               6               6               7
# TTTGTTGTCACGAACT-1-VTA_2               7               8               5
# TTTGTTGTCAGAGCAG-1-VTA_2               2               2               2
# TTTGTTGTCCTCTTTC-1-VTA_2              11              12              12
#
#                          leiden_res_1.20 leiden_res_1.50 Neuron_merge
# AAACCCAAGACTGTTC-1-VTA_1               0               0       Neuron
# AAACCCACATACCGTA-1-VTA_1               2               2   Non-neuron
# AAACCCAGTAACGCGA-1-VTA_1               4               4       Neuron
# AAACCCAGTCACTAGT-1-VTA_1               5               5       Neuron
# AAACGAAAGAGCATTA-1-VTA_1              10              11       Neuron
# ...                                  ...             ...          ...
# TTTGTTGGTTCCCACT-1-VTA_2               5               9       Neuron
# TTTGTTGGTTTAGACC-1-VTA_2              11              12   Non-neuron
# TTTGTTGTCACGAACT-1-VTA_2               6              14       Neuron
# TTTGTTGTCAGAGCAG-1-VTA_2               3               3   Non-neuron
# TTTGTTGTCCTCTTTC-1-VTA_2              16              10       Neuron
#
# [23014 rows x 13 columns]

# %%
del adata.obs['leiden_res_0.50']
del adata.obs['leiden_res_0.80']
del adata.obs['leiden_res_1.00']
del adata.obs['leiden_res_1.20']
del adata.obs['leiden_res_1.50']

# %%
for res in [0.5,0.8,1.0,1.2,1.5]:
    sc.tl.leiden(
        adata, key_added=f"leiden_res_{res:4.2f}", resolution=res, flavor="igraph"
    )
# Out:
# running Leiden clustering
#     finished: found 24 clusters and added
#     'leiden_res_0.50', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 32 clusters and added
#     'leiden_res_0.80', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 35 clusters and added
#     'leiden_res_1.00', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 37 clusters and added
#     'leiden_res_1.20', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 41 clusters and added
#     'leiden_res_1.50', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
sc.pl.umap(
    adata,
    color=["Sample","Neuron","leiden_res_0.50", "leiden_res_0.80","leiden_res_1.00","leiden_res_1.20","leiden_res_1.50"],
    legend_loc="on data",legend_fontsize=8
)

# %%
marker_gene = ['Slc17a6','Slc17a7','Slc17a8','Snap25','Slc32a1','Slc18a2','Gad1','Gad2','Aldh1a1','Th','Ddc']

# %%
for res in [0.5,0.8,1.0,1.2,1.5]:
    sc.tl.dendrogram(adata, groupby=f"leiden_res_{res:4.2f}")
# Out:
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_leiden_res_0.50']`
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_leiden_res_0.80']`
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_leiden_res_1.00']`
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_leiden_res_1.20']`
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_leiden_res_1.50']`

# %%
sc.pl.dotplot(adata, marker_gene,groupby=["leiden_res_0.50"],cmap='viridis_r',dendrogram=True)

# %%
Neuron = []
for i in range(adata.shape[0]):
    if (int(adata.obs['leiden_res_0.50'][i]) in (3,10,0,8,7,11,4,19,15,5,1,21,16,23)): 
        Neuron.append('Neuron')
    else: 
        Neuron.append('Non-neuron')
adata.obs['Neuron_merge'] = Neuron
# Out:
# /var/folders/r4/hfj1yx3s3bd93mtgxzfwcfyc0000gn/T/ipykernel_80056/1743523894.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (int(adata.obs['leiden_res_0.50'][i]) in (3,10,0,8,7,11,4,19,15,5,1,21,16,23)):

# %%
sc.pl.umap(
    adata,
    color=["Sample","Neuron","Neuron_merge","leiden_res_0.50"],
    legend_loc="on data",legend_fontsize=8
)

# %%
sc.pl.umap(
    adata,
    color=["Sample","Neuron","Neuron_merge","leiden_res_0.50"],
    legend_loc="on data",legend_fontsize=8,save = 'allcell_merge_neuron.pdf'
)
# Out:
# WARNING: saving figure to file figures/umapallcell_merge_neuron.pdf

# %%
adata.write('VTA_allcell_merge_harmony.h5ad')

# %%
adata = sc.read_h5ad('VTA_allcell_merge_harmony.h5ad')

# %%
sc.pl.umap(
    adata,
    color=["Gpr37","Gpr158","Neuron"],
    legend_fontsize=8,cmap='Spectral_r'
)

# %%
sc.pl.umap(
    adata,
    color="Gpr158",
    legend_fontsize=8,cmap='Spectral_r',vmax = 3.5
)

# %%
adata=sc.read_h5ad('VTA_allcell_merge_harmony.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 23014 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'Neuron', 'Sample', 'leiden_res_0.50', 'leiden_res_0.80', 'leiden_res_1.00', 'leiden_res_1.20', 'leiden_res_1.50', 'Neuron_merge'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Neuron_colors', 'Neuron_merge_colors', 'Sample_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'dendrogram_leiden_res_1.20', 'dendrogram_leiden_res_1.50', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 23014 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'Neuron', 'Sample', 'leiden_res_1.00', 'leiden_res_1.20', 'Neuron_merge', 'Class_new'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Neuron_colors', 'Neuron_merge_colors', 'Sample_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'dendrogram_leiden_res_1.20', 'dendrogram_leiden_res_1.50', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs
# Out:
#                           n_genes  percent_mito  n_counts  doublet_score  \
# AAACCCAAGACTGTTC-1-VTA_1     2892           0.0    6381.0       0.093149
# AAACCCACATACCGTA-1-VTA_1     1016           0.0    1703.0       0.046853
# AAACCCAGTAACGCGA-1-VTA_1     4184           0.0   10386.0       0.089820
# AAACCCAGTCACTAGT-1-VTA_1     3622           0.0    8986.0       0.032307
# AAACGAAAGAGCATTA-1-VTA_1     1570           0.0    2479.0       0.013114
# ...                           ...           ...       ...            ...
# TTTGTTGGTTCCCACT-1-VTA_2     2275           0.0    4429.0       0.039110
# TTTGTTGGTTTAGACC-1-VTA_2     1140           0.0    1956.0       0.012198
# TTTGTTGTCACGAACT-1-VTA_2     4517           0.0   13127.0       0.111898
# TTTGTTGTCAGAGCAG-1-VTA_2     1271           0.0    2199.0       0.019010
# TTTGTTGTCCTCTTTC-1-VTA_2     1334           0.0    2163.0       0.035227
#
#                           predicted_doublet      Neuron Sample  \
# AAACCCAAGACTGTTC-1-VTA_1              False      Neuron  VTA_1
# AAACCCACATACCGTA-1-VTA_1              False  Non-neuron  VTA_1
# AAACCCAGTAACGCGA-1-VTA_1              False      Neuron  VTA_1
# AAACCCAGTCACTAGT-1-VTA_1              False      Neuron  VTA_1
# AAACGAAAGAGCATTA-1-VTA_1              False      Neuron  VTA_1
# ...                                     ...         ...    ...
# TTTGTTGGTTCCCACT-1-VTA_2              False      Neuron  VTA_2
# TTTGTTGGTTTAGACC-1-VTA_2              False  Non-neuron  VTA_2
# TTTGTTGTCACGAACT-1-VTA_2              False      Neuron  VTA_2
# TTTGTTGTCAGAGCAG-1-VTA_2              False  Non-neuron  VTA_2
# TTTGTTGTCCTCTTTC-1-VTA_2              False      Neuron  VTA_2
#
#                          leiden_res_1.00 leiden_res_1.20 Neuron_merge  \
# AAACCCAAGACTGTTC-1-VTA_1               0               0       Neuron
# AAACCCACATACCGTA-1-VTA_1               1               2   Non-neuron
# AAACCCAGTAACGCGA-1-VTA_1               3               4       Neuron
# AAACCCAGTCACTAGT-1-VTA_1               4               5       Neuron
# AAACGAAAGAGCATTA-1-VTA_1               6              10       Neuron
# ...                                  ...             ...          ...
# TTTGTTGGTTCCCACT-1-VTA_2               4               5       Neuron
# TTTGTTGGTTTAGACC-1-VTA_2               7              11   Non-neuron
# TTTGTTGTCACGAACT-1-VTA_2               5               6       Neuron
# TTTGTTGTCAGAGCAG-1-VTA_2               2               3   Non-neuron
# TTTGTTGTCCTCTTTC-1-VTA_2              12              16       Neuron
#
#                            Class_new
# AAACCCAAGACTGTTC-1-VTA_1   GABA-Glut
# AAACCCACATACCGTA-1-VTA_1  Non-neuron
# AAACCCAGTAACGCGA-1-VTA_1        Glut
# AAACCCAGTCACTAGT-1-VTA_1   GABA-Glut
# AAACGAAAGAGCATTA-1-VTA_1        Dopa
# ...                              ...
# TTTGTTGGTTCCCACT-1-VTA_2        Glut
# TTTGTTGGTTTAGACC-1-VTA_2  Non-neuron
# TTTGTTGTCACGAACT-1-VTA_2   GABA-Glut
# TTTGTTGTCAGAGCAG-1-VTA_2  Non-neuron
# TTTGTTGTCCTCTTTC-1-VTA_2        Glut
#
# [23014 rows x 11 columns]

# %%
sc.pl.umap(
    adata,
    color="Class_new",
    legend_fontsize=8,legend_loc="on data"
)

# %%
del adata.obs['leiden_res_0.50']
del adata.obs['leiden_res_0.80']
del adata.obs['leiden_res_1.00']
del adata.obs['leiden_res_1.20']
del adata.obs['leiden_res_1.50']

# %%
neuron_merge = adata[adata.obs['Neuron_merge'] == 'Neuron',:]

# %%
neuron_merge
# Out:
# View of AnnData object with n_obs × n_vars = 11906 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'Neuron', 'Sample', 'Neuron_merge'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Neuron_colors', 'Neuron_merge_colors', 'Sample_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'dendrogram_leiden_res_1.20', 'dendrogram_leiden_res_1.50', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(
    neuron_merge,
    color=["Gpr37","Gpr158","Neuron","Neuron_merge"],
    legend_fontsize=8,cmap='Spectral_r'
)

# %%
neuron_merge.write('VTA_Neuron.h5ad')

# %%
neuron = adata[adata.obs['Neuron'] == 'Neuron',:]

# %%
neuron
# Out:
# View of AnnData object with n_obs × n_vars = 11604 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'Neuron', 'Sample', 'Neuron_merge'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Neuron_colors', 'Neuron_merge_colors', 'Sample_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'dendrogram_leiden_res_1.20', 'dendrogram_leiden_res_1.50', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(
    neuron,
    color=["Gpr37","Gpr158","Neuron","Neuron_merge"],
    legend_fontsize=8,cmap='Spectral_r'
)

# %%
from collections import Counter

# %%
neuron_count = Counter(list(adata.obs.Neuron_merge))

# %%
neuron_count
# Out:
# Counter({'Neuron': 11906, 'Non-neuron': 11108})

# %%
neuron
# Out:
# View of AnnData object with n_obs × n_vars = 11604 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'Neuron', 'Sample', 'Neuron_merge'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Neuron_colors', 'Neuron_merge_colors', 'Sample_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'dendrogram_leiden_res_1.20', 'dendrogram_leiden_res_1.50', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs['Neuron']
# Out:
# AAACCCAAGACTGTTC-1-VTA_1        Neuron
# AAACCCACATACCGTA-1-VTA_1    Non-neuron
# AAACCCAGTAACGCGA-1-VTA_1        Neuron
# AAACCCAGTCACTAGT-1-VTA_1        Neuron
# AAACGAAAGAGCATTA-1-VTA_1        Neuron
#                                ...
# TTTGTTGGTTCCCACT-1-VTA_2        Neuron
# TTTGTTGGTTTAGACC-1-VTA_2    Non-neuron
# TTTGTTGTCACGAACT-1-VTA_2        Neuron
# TTTGTTGTCAGAGCAG-1-VTA_2    Non-neuron
# TTTGTTGTCCTCTTTC-1-VTA_2        Neuron
# Name: Neuron, Length: 23014, dtype: category
# Categories (2, object): ['Neuron', 'Non-neuron']

# %%
non_neuron = adata[adata.obs['Neuron'] == 'Non-neuron',:]

# %%
non_neuron.obs
# Out:
#                           n_genes  percent_mito  n_counts  doublet_score  \
# AAACCCACATACCGTA-1-VTA_1     1016           0.0    1703.0       0.046853
# AAACGAAAGGTAAGGA-1-VTA_1      902           0.0    1472.0       0.009311
# AAACGAACAACGGGTA-1-VTA_1      922           0.0    1269.0       0.003303
# AAACGAACAGTTAGGG-1-VTA_1      879           0.0    1509.0       0.057174
# AAACGAATCCCGTAAA-1-VTA_1     1069           0.0    1714.0       0.048170
# ...                           ...           ...       ...            ...
# TTTGTTGCATCGTCCT-1-VTA_2      821           0.0    1154.0       0.003590
# TTTGTTGGTCCTTGTC-1-VTA_2      777           0.0    1112.0       0.013088
# TTTGTTGGTCTTGAGT-1-VTA_2      829           0.0    1210.0       0.021540
# TTTGTTGGTTTAGACC-1-VTA_2     1140           0.0    1956.0       0.012198
# TTTGTTGTCAGAGCAG-1-VTA_2     1271           0.0    2199.0       0.019010
#
#                           predicted_doublet      Neuron Sample Neuron_merge
# AAACCCACATACCGTA-1-VTA_1              False  Non-neuron  VTA_1   Non-neuron
# AAACGAAAGGTAAGGA-1-VTA_1              False  Non-neuron  VTA_1   Non-neuron
# AAACGAACAACGGGTA-1-VTA_1              False  Non-neuron  VTA_1   Non-neuron
# AAACGAACAGTTAGGG-1-VTA_1              False  Non-neuron  VTA_1   Non-neuron
# AAACGAATCCCGTAAA-1-VTA_1              False  Non-neuron  VTA_1   Non-neuron
# ...                                     ...         ...    ...          ...
# TTTGTTGCATCGTCCT-1-VTA_2              False  Non-neuron  VTA_2   Non-neuron
# TTTGTTGGTCCTTGTC-1-VTA_2              False  Non-neuron  VTA_2   Non-neuron
# TTTGTTGGTCTTGAGT-1-VTA_2              False  Non-neuron  VTA_2   Non-neuron
# TTTGTTGGTTTAGACC-1-VTA_2              False  Non-neuron  VTA_2   Non-neuron
# TTTGTTGTCAGAGCAG-1-VTA_2              False  Non-neuron  VTA_2   Non-neuron
#
# [11410 rows x 8 columns]

# %%
non_neuron.write('VTA_Non_neuron.h5ad')

# %%
marker_non=['Enpp6','Sox10', 'Mog','Cx3cr1','Aldh1l1', 'Gja1','Sox10', 'Pdgfra','Slc47a1', 'Slc6a13']

# %%
sc.pp.highly_variable_genes(non_neuron, min_mean=0.0125, max_mean=3, min_disp=0.5,flavor='seurat')
sc.set_figure_params(color_map='RdBu_r')
sc.tl.pca(non_neuron, svd_solver='arpack',use_highly_variable=True)
sc.pl.highly_variable_genes(non_neuron)
sc.pl.pca_variance_ratio(non_neuron, n_pcs=50, log=True)
sc.external.pp.harmony_integrate(non_neuron, 'Sample', basis='X_pca', adjusted_basis='X_harmony')
sc.pp.neighbors(non_neuron, n_neighbors=20, use_rep='X_harmony')
sc.tl.umap(non_neuron)
# Out:
# extracting highly variable genes
#     finished (0:00:00)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)
# computing PCA
#     with n_comps=50
# /opt/anaconda3/lib/python3.11/site-packages/scanpy/preprocessing/_highly_variable_genes.py:664: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns["hvg"] = {"flavor": flavor}
# /opt/anaconda3/lib/python3.11/site-packages/scanpy/preprocessing/_pca.py:374: FutureWarning: Argument `use_highly_variable` is deprecated, consider using the mask argument. Use_highly_variable=True can be called through mask_var="highly_variable". Use_highly_variable=False can be called through mask_var=None
#   warn(msg, FutureWarning)
#     finished (0:00:00)
# 2024-05-27 11:27:14,467 - harmonypy - INFO - Computing initial centroids with sklearn.KMeans...
# 2024-05-27 11:27:15,557 - harmonypy - INFO - sklearn.KMeans initialization complete.
# 2024-05-27 11:27:15,584 - harmonypy - INFO - Iteration 1 of 10
# 2024-05-27 11:27:16,710 - harmonypy - INFO - Iteration 2 of 10
# 2024-05-27 11:27:17,746 - harmonypy - INFO - Iteration 3 of 10
# 2024-05-27 11:27:18,478 - harmonypy - INFO - Converged after 3 iterations
# computing neighbors
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:11)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:07)

# %%
for res in [0.5,0.8,1.0,1.2,1.5]:
    sc.tl.leiden(
        non_neuron, key_added=f"leiden_res_{res:4.2f}", resolution=res, flavor="igraph"
    )
# Out:
# running Leiden clustering
#     finished: found 13 clusters and added
#     'leiden_res_0.50', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 14 clusters and added
#     'leiden_res_0.80', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 16 clusters and added
#     'leiden_res_1.00', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 19 clusters and added
#     'leiden_res_1.20', the cluster labels (adata.obs, categorical) (0:00:00)
# running Leiden clustering
#     finished: found 20 clusters and added
#     'leiden_res_1.50', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
sc.pl.umap(
    non_neuron,
    color=["Sample","leiden_res_0.50", "leiden_res_0.80","leiden_res_1.00","leiden_res_1.20","leiden_res_1.50"],
    legend_loc="on data",legend_fontsize=8
)

# %%
for res in [0.5,0.8,1.0,1.2,1.5]:
    sc.tl.dendrogram(non_neuron, groupby=f"leiden_res_{res:4.2f}")
# Out:
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_leiden_res_0.50']`
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_leiden_res_0.80']`
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_leiden_res_1.00']`
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_leiden_res_1.20']`
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_leiden_res_1.50']`

# %%
sc.pl.dotplot(non_neuron, marker_non,groupby=["leiden_res_0.80"],cmap='viridis_r',dendrogram=True)

# %%
sc.pl.dotplot(non_neuron, 'Gpr37',groupby=["leiden_res_0.80"],cmap='viridis_r',dendrogram=True)

# %%
neuron_new = sc.read_h5ad('VTA_neuron_update.h5ad')

# %%
neuron_new
# Out:
# AnnData object with n_obs × n_vars = 11906 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'Neuron', 'Sample', 'Neuron_merge', 'leiden_res_0.50', 'leiden_res_0.80', 'leiden_res_1.00', 'leiden_res_1.20', 'leiden_res_1.50', 'Class'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Neuron_colors', 'Neuron_merge_colors', 'Sample_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'dendrogram_leiden_res_1.20', 'dendrogram_leiden_res_1.50', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'neighbors', 'pca', 'umap'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
neuron_new.obs['Class']
# Out:
# AAACCCAAGACTGTTC-1-VTA_1    GABA-Glut
# AAACCCAGTAACGCGA-1-VTA_1         Glut
# AAACCCAGTCACTAGT-1-VTA_1    GABA-Glut
# AAACGAAAGAGCATTA-1-VTA_1         Dopa
# AAACGAAAGGTCACAG-1-VTA_1    GABA-Glut
#                               ...
# TTTGTTGGTGTCACAT-1-VTA_2         Glut
# TTTGTTGGTTACCTGA-1-VTA_2    GABA-Glut
# TTTGTTGGTTCCCACT-1-VTA_2         Glut
# TTTGTTGTCACGAACT-1-VTA_2    GABA-Glut
# TTTGTTGTCCTCTTTC-1-VTA_2         Glut
# Name: Class, Length: 11906, dtype: category
# Categories (6, object): ['Dopa', 'GABA', 'GABA-Glut', 'Glut', 'Glut-Sero', 'Non-neuron']

# %%
adata.obs
# Out:
#                           n_genes  percent_mito  n_counts  doublet_score  \
# AAACCCAAGACTGTTC-1-VTA_1     2892           0.0    6381.0       0.093149
# AAACCCACATACCGTA-1-VTA_1     1016           0.0    1703.0       0.046853
# AAACCCAGTAACGCGA-1-VTA_1     4184           0.0   10386.0       0.089820
# AAACCCAGTCACTAGT-1-VTA_1     3622           0.0    8986.0       0.032307
# AAACGAAAGAGCATTA-1-VTA_1     1570           0.0    2479.0       0.013114
# ...                           ...           ...       ...            ...
# TTTGTTGGTTCCCACT-1-VTA_2     2275           0.0    4429.0       0.039110
# TTTGTTGGTTTAGACC-1-VTA_2     1140           0.0    1956.0       0.012198
# TTTGTTGTCACGAACT-1-VTA_2     4517           0.0   13127.0       0.111898
# TTTGTTGTCAGAGCAG-1-VTA_2     1271           0.0    2199.0       0.019010
# TTTGTTGTCCTCTTTC-1-VTA_2     1334           0.0    2163.0       0.035227
#
#                           predicted_doublet      Neuron Sample  \
# AAACCCAAGACTGTTC-1-VTA_1              False      Neuron  VTA_1
# AAACCCACATACCGTA-1-VTA_1              False  Non-neuron  VTA_1
# AAACCCAGTAACGCGA-1-VTA_1              False      Neuron  VTA_1
# AAACCCAGTCACTAGT-1-VTA_1              False      Neuron  VTA_1
# AAACGAAAGAGCATTA-1-VTA_1              False      Neuron  VTA_1
# ...                                     ...         ...    ...
# TTTGTTGGTTCCCACT-1-VTA_2              False      Neuron  VTA_2
# TTTGTTGGTTTAGACC-1-VTA_2              False  Non-neuron  VTA_2
# TTTGTTGTCACGAACT-1-VTA_2              False      Neuron  VTA_2
# TTTGTTGTCAGAGCAG-1-VTA_2              False  Non-neuron  VTA_2
# TTTGTTGTCCTCTTTC-1-VTA_2              False      Neuron  VTA_2
#
#                          leiden_res_1.00 leiden_res_1.20 Neuron_merge
# AAACCCAAGACTGTTC-1-VTA_1               0               0       Neuron
# AAACCCACATACCGTA-1-VTA_1               1               2   Non-neuron
# AAACCCAGTAACGCGA-1-VTA_1               3               4       Neuron
# AAACCCAGTCACTAGT-1-VTA_1               4               5       Neuron
# AAACGAAAGAGCATTA-1-VTA_1               6              10       Neuron
# ...                                  ...             ...          ...
# TTTGTTGGTTCCCACT-1-VTA_2               4               5       Neuron
# TTTGTTGGTTTAGACC-1-VTA_2               7              11   Non-neuron
# TTTGTTGTCACGAACT-1-VTA_2               5               6       Neuron
# TTTGTTGTCAGAGCAG-1-VTA_2               2               3   Non-neuron
# TTTGTTGTCCTCTTTC-1-VTA_2              12              16       Neuron
#
# [23014 rows x 10 columns]

# %%
del adata.obs['leiden_res_0.50']
del adata.obs['leiden_res_0.80']
del adata.obs['leiden_res_1.50']

# %%
df = pd.DataFrame()
index = list(neuron_new.obs.index)
Class = list(neuron_new.obs.Class)
df.index = index
df['Class'] = Class
dic = df['Class'].to_dict()

# %%
dic
# Out:
# {'AAACCCAAGACTGTTC-1-VTA_1': 'GABA-Glut',
#  'AAACCCAGTAACGCGA-1-VTA_1': 'Glut',
#  'AAACCCAGTCACTAGT-1-VTA_1': 'GABA-Glut',
#  'AAACGAAAGAGCATTA-1-VTA_1': 'Dopa',
#  'AAACGAAAGGTCACAG-1-VTA_1': 'GABA-Glut',
#  'AAACGAAAGGTCATTC-1-VTA_1': 'GABA-Glut',
#  'AAACGAAAGGTTCCAT-1-VTA_1': 'GABA',
#  'AAACGAAGTACCGCGT-1-VTA_1': 'GABA',
#  'AAACGAAGTACTGAGG-1-VTA_1': 'Dopa',
#  'AAACGAATCACACCGG-1-VTA_1': 'Dopa',
#  'AAACGAATCTAGCCTC-1-VTA_1': 'Glut',
#  'AAACGCTAGAATCGTA-1-VTA_1': 'GABA-Glut',
#  'AAACGCTGTGCCGTTG-1-VTA_1': 'Non-neuron',
#  'AAACGCTTCAAACCTG-1-VTA_1': 'GABA',
#  'AAACGCTTCAAATGAG-1-VTA_1': 'GABA',
#  'AAACGCTTCACGATAC-1-VTA_1': 'GABA-Glut',
#  'AAAGAACAGCAACAGC-1-VTA_1': 'GABA',
#  'AAAGAACCACTAGTAC-1-VTA_1': 'GABA',
#  'AAAGGATAGCAGATAT-1-VTA_1': 'GABA-Glut',
#  'AAAGGATCACTACGGC-1-VTA_1': 'Glut',
#  'AAAGGATGTGACGCCT-1-VTA_1': 'Dopa',
#  'AAAGGGCGTCCTACGG-1-VTA_1': 'Dopa',
#  'AAAGGGCGTGTCCACG-1-VTA_1': 'Dopa',
#  'AAAGGGCTCATTGAGC-1-VTA_1': 'GABA',
#  'AAAGGGCTCTACTCAT-1-VTA_1': 'GABA-Glut',
#  'AAAGGTAAGCACGTCC-1-VTA_1': 'Dopa',
#  'AAAGGTACAACGATTC-1-VTA_1': 'GABA',
#  'AAAGGTACAAGACGGT-1-VTA_1': 'GABA',
#  'AAAGGTAGTGGACTAG-1-VTA_1': 'Non-neuron',
#  'AAAGGTAGTGGGTATG-1-VTA_1': 'GABA-Glut',
#  'AAAGTCCAGGCTTCCG-1-VTA_1': 'Non-neuron',
#  'AAAGTCCAGGTACAGC-1-VTA_1': 'GABA',
#  'AAAGTCCCAGGAAGTC-1-VTA_1': 'Glut-Sero',
#  'AAAGTCCTCAAACTGC-1-VTA_1': 'Non-neuron',
#  'AAAGTCCTCACGGAGA-1-VTA_1': 'Non-neuron',
#  'AAATGGAAGAAGTCTA-1-VTA_1': 'GABA-Glut',
#  'AAATGGACAGTGCCTG-1-VTA_1': 'GABA',
#  'AAATGGAGTTAGGCTT-1-VTA_1': 'Dopa',
#  'AAATGGATCACTTGGA-1-VTA_1': 'Dopa',
#  'AACAAAGAGAAGCTGC-1-VTA_1': 'Non-neuron',
#  'AACAAAGAGGTGCAGT-1-VTA_1': 'GABA-Glut',
#  'AACAAAGCACCAACAT-1-VTA_1': 'Non-neuron',
#  'AACAAAGCAGTAGAAT-1-VTA_1': 'GABA',
#  'AACAAAGGTCCACTTC-1-VTA_1': 'Non-neuron',
#  'AACAAAGGTTACGTAC-1-VTA_1': 'Dopa',
#  'AACAAAGTCACGAGGA-1-VTA_1': 'GABA-Glut',
#  'AACAAAGTCAGTGATC-1-VTA_1': 'Dopa',
#  'AACAAAGTCGAGAGAC-1-VTA_1': 'Dopa',
#  'AACAACCGTCACCTTC-1-VTA_1': 'Dopa',
#  'AACAACCGTCCTTGTC-1-VTA_1': 'GABA',
#  'AACAACCTCCCTCGAT-1-VTA_1': 'GABA',
#  'AACAACCTCTCTCGAC-1-VTA_1': 'Glut',
#  'AACAACCTCTGTCCCA-1-VTA_1': 'Non-neuron',
#  'AACAAGACAAAGCAAT-1-VTA_1': 'Non-neuron',
#  'AACAAGAGTCCACATA-1-VTA_1': 'GABA',
#  'AACAAGAGTCGTACTA-1-VTA_1': 'Glut',
#  'AACAAGATCTATGTGG-1-VTA_1': 'Glut',
#  'AACACACAGAAACCCG-1-VTA_1': 'GABA-Glut',
#  'AACACACAGACGGTCA-1-VTA_1': 'GABA',
#  'AACACACTCATAAGGA-1-VTA_1': 'GABA',
#  'AACACACTCGACACTA-1-VTA_1': 'GABA-Glut',
#  'AACACACTCGACCCAG-1-VTA_1': 'GABA-Glut',
#  'AACAGGGAGCTATCCA-1-VTA_1': 'GABA',
#  'AACAGGGAGGGATGTC-1-VTA_1': 'Dopa',
#  'AACAGGGCAGCTGGTC-1-VTA_1': 'GABA',
#  'AACAGGGGTACTGCGC-1-VTA_1': 'GABA-Glut',
#  'AACAGGGGTCAAAGTA-1-VTA_1': 'Glut',
#  'AACAGGGGTGATCATC-1-VTA_1': 'Dopa',
#  'AACCAACAGAAGTCCG-1-VTA_1': 'Non-neuron',
#  'AACCAACCACAGCCAC-1-VTA_1': 'Non-neuron',
#  'AACCAACCATACAGGG-1-VTA_1': 'GABA',
#  'AACCAACCATTGTGCA-1-VTA_1': 'Dopa',
#  'AACCAACGTTTACGTG-1-VTA_1': 'GABA',
#  'AACCAACTCCCTTGTG-1-VTA_1': 'Non-neuron',
#  'AACCACACACATACGT-1-VTA_1': 'Non-neuron',
#  'AACCACACACGCCACA-1-VTA_1': 'GABA-Glut',
#  'AACCACAGTAATCAAG-1-VTA_1': 'GABA',
#  'AACCACATCGAGAGAC-1-VTA_1': 'Glut',
#  'AACCATGAGCCGGAAT-1-VTA_1': 'GABA',
#  'AACCATGAGTGGATAT-1-VTA_1': 'Dopa',
#  'AACCATGAGTTAACGA-1-VTA_1': 'GABA',
#  'AACCATGCAATCGCCG-1-VTA_1': 'Glut',
#  'AACCATGCATGTCAGT-1-VTA_1': 'Dopa',
#  'AACCATGGTTTATGCG-1-VTA_1': 'Glut',
#  'AACCCAAAGCCTAACT-1-VTA_1': 'Dopa',
#  'AACCCAACAGCCCAGT-1-VTA_1': 'Non-neuron',
#  'AACCCAACAGTCGGTC-1-VTA_1': 'Non-neuron',
#  'AACCCAAGTGAGACCA-1-VTA_1': 'Glut-Sero',
#  'AACCTGAAGAGTTCGG-1-VTA_1': 'GABA-Glut',
#  'AACCTGAAGTGAGCCA-1-VTA_1': 'GABA-Glut',
#  'AACCTGACAACAGATA-1-VTA_1': 'GABA',
#  'AACCTGAGTCCAGAAG-1-VTA_1': 'Dopa',
#  'AACCTGATCCCGAGTG-1-VTA_1': 'GABA',
#  'AACCTGATCGCAACAT-1-VTA_1': 'Glut',
#  'AACCTGATCGTTACCC-1-VTA_1': 'Glut',
#  'AACCTTTGTATTGACC-1-VTA_1': 'GABA-Glut',
#  'AACCTTTGTTCAAACC-1-VTA_1': 'GABA-Glut',
#  'AACCTTTTCTTAGTTC-1-VTA_1': 'Dopa',
#  'AACGAAAAGATAACAC-1-VTA_1': 'Glut',
#  'AACGAAAAGGTGGTTG-1-VTA_1': 'GABA',
#  'AACGAAAAGTTCATGC-1-VTA_1': 'Glut-Sero',
#  'AACGAAACAACAGCTT-1-VTA_1': 'Non-neuron',
#  'AACGAAACACATGACT-1-VTA_1': 'Glut',
#  'AACGAAACACGAGGAT-1-VTA_1': 'GABA-Glut',
#  'AACGAAAGTAAGAACT-1-VTA_1': 'GABA-Glut',
#  'AACGAAAGTCTAGGTT-1-VTA_1': 'GABA-Glut',
#  'AACGAAATCGTACCTC-1-VTA_1': 'Glut-Sero',
#  'AACGGGAAGAAGAACG-1-VTA_1': 'GABA',
#  'AACGGGACAGACTGCC-1-VTA_1': 'Dopa',
#  'AACGGGATCGTCTCAC-1-VTA_1': 'GABA-Glut',
#  'AACGTCAGTTCAAGGG-1-VTA_1': 'Dopa',
#  'AACGTCATCACACCGG-1-VTA_1': 'Dopa',
#  'AACGTCATCCGCGATG-1-VTA_1': 'GABA',
#  'AACTTCTAGGTCACCC-1-VTA_1': 'GABA-Glut',
#  'AACTTCTCAAGGATGC-1-VTA_1': 'GABA-Glut',
#  'AACTTCTCACAAGCAG-1-VTA_1': 'GABA-Glut',
#  'AACTTCTCACGAAAGC-1-VTA_1': 'GABA',
#  'AACTTCTCAGGGCTTC-1-VTA_1': 'GABA',
#  'AACTTCTGTGAGGAAA-1-VTA_1': 'GABA-Glut',
#  'AACTTCTTCACGTAGT-1-VTA_1': 'GABA',
#  'AACTTCTTCCGTCAAA-1-VTA_1': 'Non-neuron',
#  'AAGAACAAGGCTCCCA-1-VTA_1': 'Non-neuron',
#  'AAGAACACATCCGAGC-1-VTA_1': 'GABA-Glut',
#  'AAGAACAGTCTACTGA-1-VTA_1': 'Non-neuron',
#  'AAGAACATCACCTGGG-1-VTA_1': 'Glut',
#  'AAGAACATCTGGCTGG-1-VTA_1': 'GABA',
#  'AAGACAAAGCCTTTCC-1-VTA_1': 'GABA-Glut',
#  'AAGACAAAGGTCATCT-1-VTA_1': 'Glut',
#  'AAGACAAAGTCACTCA-1-VTA_1': 'Non-neuron',
#  'AAGACAAAGTTCCATG-1-VTA_1': 'GABA-Glut',
#  'AAGACAACACCTGCGA-1-VTA_1': 'Non-neuron',
#  'AAGACAACAGAACTTC-1-VTA_1': 'GABA',
#  'AAGACAAGTAACTGCT-1-VTA_1': 'GABA',
#  'AAGACAATCCACGTAA-1-VTA_1': 'GABA-Glut',
#  'AAGACTCAGTTGTCAC-1-VTA_1': 'GABA-Glut',
#  'AAGACTCGTACCGCGT-1-VTA_1': 'GABA-Glut',
#  'AAGACTCGTCGCATCG-1-VTA_1': 'GABA-Glut',
#  'AAGACTCGTGCTATTG-1-VTA_1': 'GABA-Glut',
#  'AAGACTCGTGTATACC-1-VTA_1': 'GABA',
#  'AAGACTCTCAGCTCTC-1-VTA_1': 'GABA-Glut',
#  'AAGATAGAGAACTTCC-1-VTA_1': 'GABA-Glut',
#  'AAGATAGAGATGGTAT-1-VTA_1': 'GABA-Glut',
#  'AAGCATCAGCAACTTC-1-VTA_1': 'Non-neuron',
#  'AAGCATCAGCCTGAGA-1-VTA_1': 'GABA-Glut',
#  'AAGCATCCATCGCTGG-1-VTA_1': 'Dopa',
#  'AAGCATCCATGCAGGA-1-VTA_1': 'GABA-Glut',
#  'AAGCATCGTGACTATC-1-VTA_1': 'GABA-Glut',
#  'AAGCATCTCACCGGGT-1-VTA_1': 'Glut',
#  'AAGCCATAGGCTTAAA-1-VTA_1': 'GABA-Glut',
#  'AAGCGAGAGAATTCAG-1-VTA_1': 'Non-neuron',
#  'AAGCGAGCACTAGGTT-1-VTA_1': 'GABA',
#  'AAGCGAGTCCCAGCGA-1-VTA_1': 'GABA-Glut',
#  'AAGCGAGTCTTCTGTA-1-VTA_1': 'GABA-Glut',
#  'AAGCGTTAGCAGTACG-1-VTA_1': 'GABA',
#  'AAGCGTTAGGAGTACC-1-VTA_1': 'Dopa',
#  'AAGCGTTCACGACTAT-1-VTA_1': 'Glut',
#  'AAGCGTTGTCCAGGTC-1-VTA_1': 'GABA-Glut',
#  'AAGCGTTGTTAGCGGA-1-VTA_1': 'GABA-Glut',
#  'AAGCGTTTCTAGACCA-1-VTA_1': 'Glut-Sero',
#  'AAGGAATAGCAGATAT-1-VTA_1': 'GABA',
#  'AAGGAATAGGGATCAC-1-VTA_1': 'Dopa',
#  'AAGGAATCAGACCTAT-1-VTA_1': 'Dopa',
#  'AAGGAATGTGATTCAC-1-VTA_1': 'Glut',
#  'AAGGAATGTTAATCGC-1-VTA_1': 'GABA',
#  'AAGGTAAAGCTAAACA-1-VTA_1': 'Non-neuron',
#  'AAGGTAACAATCGTCA-1-VTA_1': 'GABA',
#  'AAGGTAACAGCTTTCC-1-VTA_1': 'Dopa',
#  'AAGGTAACATGTTACG-1-VTA_1': 'GABA-Glut',
#  'AAGGTAATCCCAAGTA-1-VTA_1': 'Non-neuron',
#  'AAGGTAATCGTTAGTG-1-VTA_1': 'Glut',
#  'AAGTACCGTAGTACGG-1-VTA_1': 'GABA-Glut',
#  'AAGTACCGTGTTTGCA-1-VTA_1': 'GABA-Glut',
#  'AAGTACCTCAAGTAAG-1-VTA_1': 'Dopa',
#  'AAGTCGTCACCTGATA-1-VTA_1': 'GABA-Glut',
#  'AAGTCGTCATCTTAGG-1-VTA_1': 'GABA',
#  'AAGTGAACATACGCAT-1-VTA_1': 'GABA-Glut',
#  'AAGTGAACATAGAAAC-1-VTA_1': 'Dopa',
#  'AAGTGAACATGACTCA-1-VTA_1': 'Dopa',
#  'AAGTGAAGTGGTCTTA-1-VTA_1': 'Dopa',
#  'AAGTGAAGTGTTCATG-1-VTA_1': 'GABA',
#  'AAGTGAAGTTCCTAAG-1-VTA_1': 'GABA-Glut',
#  'AAGTTCGAGACTTCCA-1-VTA_1': 'Dopa',
#  'AAGTTCGAGAGATCGC-1-VTA_1': 'Dopa',
#  'AAGTTCGAGATCGCTT-1-VTA_1': 'GABA-Glut',
#  'AAGTTCGAGCTCGGCT-1-VTA_1': 'GABA-Glut',
#  'AAGTTCGCACACCAGC-1-VTA_1': 'GABA',
#  'AAGTTCGCACTGTCCT-1-VTA_1': 'GABA-Glut',
#  'AAGTTCGCATCCCGTT-1-VTA_1': 'GABA-Glut',
#  'AAGTTCGGTACGAAAT-1-VTA_1': 'GABA-Glut',
#  'AAGTTCGGTCGCATCG-1-VTA_1': 'Glut',
#  'AAGTTCGGTTGCATCA-1-VTA_1': 'GABA',
#  'AAGTTCGTCCGTGTCT-1-VTA_1': 'GABA',
#  'AATAGAGAGAGATTCA-1-VTA_1': 'GABA-Glut',
#  'AATAGAGCATTGACAC-1-VTA_1': 'GABA',
#  'AATAGAGGTCACCTTC-1-VTA_1': 'GABA-Glut',
#  'AATAGAGGTCACTCGG-1-VTA_1': 'Dopa',
#  'AATAGAGTCATAGACC-1-VTA_1': 'GABA-Glut',
#  'AATAGAGTCCAGCACG-1-VTA_1': 'GABA',
#  'AATAGAGTCGATACGT-1-VTA_1': 'GABA-Glut',
#  'AATAGAGTCTATCCAT-1-VTA_1': 'GABA-Glut',
#  'AATAGAGTCTTCGACC-1-VTA_1': 'GABA',
#  'AATCACGCAGGTCTCG-1-VTA_1': 'GABA',
#  'AATCACGGTCTCGACG-1-VTA_1': 'GABA-Glut',
#  'AATCACGTCGTGGGTC-1-VTA_1': 'GABA-Glut',
#  'AATCACGTCTACACAG-1-VTA_1': 'Dopa',
#  'AATCACGTCTGACGCG-1-VTA_1': 'GABA-Glut',
#  'AATCGACAGACCTCAT-1-VTA_1': 'Dopa',
#  'AATCGACAGTCTCCTC-1-VTA_1': 'GABA',
#  'AATCGACCAGGCTACC-1-VTA_1': 'Dopa',
#  'AATCGACGTCGTTTCC-1-VTA_1': 'GABA-Glut',
#  'AATCGACGTCTTCATT-1-VTA_1': 'Glut',
#  'AATCGACTCTGCATGA-1-VTA_1': 'GABA',
#  'AATCGTGCAAACGGCA-1-VTA_1': 'GABA',
#  'AATCGTGTCAGATGCT-1-VTA_1': 'GABA-Glut',
#  'AATCGTGTCAGTCAGT-1-VTA_1': 'GABA',
#  'AATCGTGTCTACGGGC-1-VTA_1': 'Non-neuron',
#  'AATCGTGTCTAGTGAC-1-VTA_1': 'GABA-Glut',
#  'AATCGTGTCTGTCCGT-1-VTA_1': 'Glut',
#  'AATGAAGAGATGGCGT-1-VTA_1': 'GABA',
#  'AATGAAGAGCCGTTAT-1-VTA_1': 'GABA',
#  'AATGAAGCACCTGTCT-1-VTA_1': 'GABA',
#  'AATGAAGCACGGTGAA-1-VTA_1': 'GABA-Glut',
#  'AATGAAGCATTGTACG-1-VTA_1': 'Non-neuron',
#  'AATGAAGCATTGTAGC-1-VTA_1': 'GABA-Glut',
#  'AATGAAGGTGGTATGG-1-VTA_1': 'GABA-Glut',
#  'AATGAAGGTTCCTACC-1-VTA_1': 'GABA-Glut',
#  'AATGAAGTCGAAACAA-1-VTA_1': 'Non-neuron',
#  'AATGACCAGCTCTTCC-1-VTA_1': 'GABA',
#  'AATGACCAGGAACATT-1-VTA_1': 'GABA',
#  'AATGACCAGTTGCTCA-1-VTA_1': 'GABA-Glut',
#  'AATGACCCACAGGATG-1-VTA_1': 'GABA',
#  'AATGACCGTCTGCAAT-1-VTA_1': 'Dopa',
#  'AATGACCGTGTTTGCA-1-VTA_1': 'GABA',
#  'AATGACCTCATTTGTC-1-VTA_1': 'GABA',
#  'AATGACCTCTAATTCC-1-VTA_1': 'Non-neuron',
#  'AATGACCTCTCCAATT-1-VTA_1': 'Non-neuron',
#  'AATGCCAAGACGTCCC-1-VTA_1': 'GABA-Glut',
#  'AATGCCAAGCTATCCA-1-VTA_1': 'GABA',
#  'AATGCCAAGCTTCGTA-1-VTA_1': 'GABA-Glut',
#  'AATGCCAAGTATGACA-1-VTA_1': 'Dopa',
#  'AATGCCACATCAACCA-1-VTA_1': 'GABA',
#  'AATGCCACATGATAGA-1-VTA_1': 'GABA',
#  'AATGCCAGTAGCACGA-1-VTA_1': 'GABA',
#  'AATGCCAGTCATAGTC-1-VTA_1': 'GABA-Glut',
#  'AATGCCAGTTAAGGAT-1-VTA_1': 'Dopa',
#  'AATGCCATCGGCTGGT-1-VTA_1': 'GABA-Glut',
#  'AATGCCATCTTCTAAC-1-VTA_1': 'Dopa',
#  'AATGGAAAGACATCAA-1-VTA_1': 'GABA',
#  'AATGGAAAGAGGCGTT-1-VTA_1': 'GABA',
#  'AATGGAAGTGAAGCGT-1-VTA_1': 'Non-neuron',
#  'AATGGAATCAGAGCGA-1-VTA_1': 'Glut',
#  'AATGGCTAGGCTTCCG-1-VTA_1': 'GABA',
#  'AATGGCTGTGAGATCG-1-VTA_1': 'Glut-Sero',
#  'AATGGCTTCAAAGCCT-1-VTA_1': 'GABA-Glut',
#  'AATGGCTTCAGACCGC-1-VTA_1': 'GABA',
#  'AATGGCTTCATCACAG-1-VTA_1': 'Non-neuron',
#  'AATGGCTTCGGACCAC-1-VTA_1': 'Dopa',
#  'AATTCCTAGAGCCCAA-1-VTA_1': 'GABA',
#  'AATTCCTAGTAAAGCT-1-VTA_1': 'Dopa',
#  'AATTCCTCAGAATGTA-1-VTA_1': 'GABA-Glut',
#  'AATTCCTGTGACCTGC-1-VTA_1': 'Dopa',
#  'AATTTCCCAATTCTCT-1-VTA_1': 'GABA-Glut',
#  'AATTTCCCAGGTTACT-1-VTA_1': 'GABA',
#  'AATTTCCGTCGTTTCC-1-VTA_1': 'GABA-Glut',
#  'AATTTCCTCCGCAACG-1-VTA_1': 'GABA-Glut',
#  'ACAAAGAAGAATCGAT-1-VTA_1': 'Glut',
#  'ACAAAGAAGCTGCCTG-1-VTA_1': 'GABA-Glut',
#  'ACAAAGACAGCCTTCT-1-VTA_1': 'GABA-Glut',
#  'ACAAAGAGTACGAAAT-1-VTA_1': 'GABA-Glut',
#  'ACAAAGATCACGATAC-1-VTA_1': 'Dopa',
#  'ACAACCAAGAACCGCA-1-VTA_1': 'Non-neuron',
#  'ACAACCACAATCACGT-1-VTA_1': 'Dopa',
#  'ACAACCACAGCAGTAG-1-VTA_1': 'GABA-Glut',
#  'ACAACCAGTCCACACG-1-VTA_1': 'GABA',
#  'ACAACCATCACCGACG-1-VTA_1': 'Non-neuron',
#  'ACAAGCTAGCACTCAT-1-VTA_1': 'Glut-Sero',
#  'ACAAGCTCAAGTCGTT-1-VTA_1': 'GABA-Glut',
#  'ACAAGCTCACTACACA-1-VTA_1': 'Dopa',
#  'ACAAGCTGTCAGGTAG-1-VTA_1': 'Non-neuron',
#  'ACAAGCTGTGCGTGCT-1-VTA_1': 'Non-neuron',
#  'ACAAGCTGTGTGAGCA-1-VTA_1': 'GABA-Glut',
#  'ACAAGCTTCCATTTCA-1-VTA_1': 'GABA',
#  'ACAAGCTTCCCTCTCC-1-VTA_1': 'GABA-Glut',
#  'ACACAGTCACCGTCGA-1-VTA_1': 'Dopa',
#  'ACACAGTTCAATCAGC-1-VTA_1': 'Dopa',
#  'ACACAGTTCACCATGA-1-VTA_1': 'GABA',
#  'ACACAGTTCAGCAATC-1-VTA_1': 'GABA-Glut',
#  'ACACAGTTCGTAGCCG-1-VTA_1': 'Glut',
#  'ACACCAAAGGCATCAG-1-VTA_1': 'Dopa',
#  'ACACCAACACGGTGTC-1-VTA_1': 'Glut',
#  'ACACCAACAGGCTACC-1-VTA_1': 'GABA',
#  'ACACCAAGTTACCCTC-1-VTA_1': 'GABA-Glut',
#  'ACACCAATCATCCTAT-1-VTA_1': 'Non-neuron',
#  'ACACCAATCGCCTCTA-1-VTA_1': 'Non-neuron',
#  'ACACGCGCACTGAGTT-1-VTA_1': 'Glut',
#  'ACACGCGCAGCTGTGC-1-VTA_1': 'GABA-Glut',
#  'ACACTGACAACGCATT-1-VTA_1': 'Glut',
#  'ACACTGACACGTTCGG-1-VTA_1': 'GABA-Glut',
#  'ACACTGACACTTCCTG-1-VTA_1': 'Glut',
#  'ACACTGAGTACCTTCC-1-VTA_1': 'GABA-Glut',
#  'ACACTGAGTGGTCTGC-1-VTA_1': 'GABA-Glut',
#  'ACACTGAGTGTTCGTA-1-VTA_1': 'GABA-Glut',
#  'ACACTGATCGCTAATG-1-VTA_1': 'GABA-Glut',
#  'ACAGAAAAGTAACCTC-1-VTA_1': 'Non-neuron',
#  'ACAGAAAAGTTCCTGA-1-VTA_1': 'GABA-Glut',
#  'ACAGAAACATCATCCC-1-VTA_1': 'Non-neuron',
#  'ACAGAAAGTATGCTAC-1-VTA_1': 'Non-neuron',
#  'ACAGAAAGTGAGTTGG-1-VTA_1': 'GABA-Glut',
#  'ACAGAAAGTTGAGGAC-1-VTA_1': 'GABA',
#  'ACAGAAATCACGATAC-1-VTA_1': 'GABA-Glut',
#  'ACAGCCGCAATGTGGG-1-VTA_1': 'GABA',
#  'ACAGCCGCACTGTCGG-1-VTA_1': 'GABA',
#  'ACAGCCGTCAGCTAGT-1-VTA_1': 'Glut',
#  'ACAGGGAAGACATATG-1-VTA_1': 'Glut',
#  'ACAGGGAAGCTTGTGT-1-VTA_1': 'Non-neuron',
#  'ACAGGGAAGTGAATAC-1-VTA_1': 'GABA-Glut',
#  'ACAGGGACAACTGTGT-1-VTA_1': 'Glut',
#  'ACAGGGACACTGTTCC-1-VTA_1': 'GABA',
#  'ACAGGGACAGCTACCG-1-VTA_1': 'GABA-Glut',
#  'ACAGGGAGTATCCCAA-1-VTA_1': 'GABA',
#  'ACAGGGAGTCACCGCA-1-VTA_1': 'GABA-Glut',
#  'ACAGGGAGTGATATAG-1-VTA_1': 'Dopa',
#  'ACAGGGATCAGTGTGT-1-VTA_1': 'Glut',
#  'ACAGGGATCGTCAAAC-1-VTA_1': 'Glut',
#  'ACAGGGATCTAGTACG-1-VTA_1': 'GABA-Glut',
#  'ACATCCCAGCTGCGAA-1-VTA_1': 'GABA-Glut',
#  'ACATCCCAGGATCATA-1-VTA_1': 'GABA-Glut',
#  'ACATCCCAGTTGCCCG-1-VTA_1': 'GABA-Glut',
#  'ACATCCCCAAGGCCTC-1-VTA_1': 'Glut',
#  'ACATCCCCACACCGCA-1-VTA_1': 'GABA',
#  'ACATCCCCACCACTGG-1-VTA_1': 'GABA-Glut',
#  'ACATCCCCAGCTACAT-1-VTA_1': 'GABA-Glut',
#  'ACATCCCGTACCAGAG-1-VTA_1': 'GABA-Glut',
#  'ACATCCCGTCGCACGT-1-VTA_1': 'GABA',
#  'ACATCCCGTGCAATAA-1-VTA_1': 'GABA-Glut',
#  'ACATCCCGTGCTCTCT-1-VTA_1': 'GABA',
#  'ACATCCCGTGGGATTG-1-VTA_1': 'GABA-Glut',
#  'ACATCCCTCAACGCTA-1-VTA_1': 'GABA',
#  'ACATCCCTCCAGTTCC-1-VTA_1': 'GABA',
#  'ACATCGACATCGATCA-1-VTA_1': 'GABA-Glut',
#  'ACATCGAGTCTGTCAA-1-VTA_1': 'GABA-Glut',
#  'ACATCGATCCACAGCG-1-VTA_1': 'GABA-Glut',
#  'ACATCGATCGTGCTCT-1-VTA_1': 'GABA-Glut',
#  'ACATGCACAGGAGGTT-1-VTA_1': 'GABA-Glut',
#  'ACATGCACATGAAGCG-1-VTA_1': 'Dopa',
#  'ACATGCAGTTGGGATG-1-VTA_1': 'Glut-Sero',
#  'ACATGCATCACCCTTG-1-VTA_1': 'Dopa',
#  'ACATGCATCTTTACAC-1-VTA_1': 'GABA',
#  'ACATTTCAGCACAAAT-1-VTA_1': 'Glut',
#  'ACATTTCCAGGTGACA-1-VTA_1': 'GABA-Glut',
#  'ACATTTCGTTGACTGT-1-VTA_1': 'Dopa',
#  'ACATTTCTCGAATCCA-1-VTA_1': 'GABA',
#  'ACATTTCTCTCCGAAA-1-VTA_1': 'Glut',
#  'ACCAAACAGACGATAT-1-VTA_1': 'Non-neuron',
#  'ACCAAACAGGCTTCCG-1-VTA_1': 'GABA-Glut',
#  'ACCAAACCACTAAACC-1-VTA_1': 'Non-neuron',
#  'ACCAAACCAGCTGCCA-1-VTA_1': 'Dopa',
#  'ACCAAACGTCCCTGTT-1-VTA_1': 'Dopa',
#  'ACCAAACTCCCAGTGG-1-VTA_1': 'Glut',
#  'ACCAAACTCGAACTCA-1-VTA_1': 'GABA-Glut',
#  'ACCAACAAGCCAGACA-1-VTA_1': 'Non-neuron',
#  'ACCAACAAGCTAGAGC-1-VTA_1': 'GABA-Glut',
#  'ACCAACACAAACTAGA-1-VTA_1': 'GABA-Glut',
#  'ACCAACACAAAGGATT-1-VTA_1': 'GABA-Glut',
#  'ACCAACACAGCTTTGA-1-VTA_1': 'Dopa',
#  'ACCAACAGTAACGTTC-1-VTA_1': 'Glut-Sero',
#  'ACCAACAGTTGACTAC-1-VTA_1': 'Non-neuron',
#  'ACCAACATCCACGTCT-1-VTA_1': 'GABA-Glut',
#  'ACCAACATCTCCCAAC-1-VTA_1': 'Non-neuron',
#  'ACCACAAAGCGGACAT-1-VTA_1': 'Dopa',
#  'ACCACAAGTTTCGTTT-1-VTA_1': 'GABA-Glut',
#  'ACCACAATCTCTCTAA-1-VTA_1': 'Glut',
#  'ACCATTTAGCCATCCG-1-VTA_1': 'GABA-Glut',
#  'ACCATTTAGTAAAGCT-1-VTA_1': 'GABA-Glut',
#  'ACCATTTAGTCTAACC-1-VTA_1': 'GABA-Glut',
#  'ACCATTTCACTCACTC-1-VTA_1': 'Glut',
#  'ACCATTTCACTGCATA-1-VTA_1': 'GABA',
#  'ACCATTTTCCCTGTTG-1-VTA_1': 'Glut',
#  'ACCCAAAAGAGACAAG-1-VTA_1': 'Non-neuron',
#  'ACCCAAAAGAGCTTTC-1-VTA_1': 'Glut-Sero',
#  'ACCCAAAAGGTAAGAG-1-VTA_1': 'GABA-Glut',
#  'ACCCAAAAGGTTGTTC-1-VTA_1': 'GABA-Glut',
#  'ACCCAAACATCGATAC-1-VTA_1': 'GABA-Glut',
#  'ACCCAAATCAATCCAG-1-VTA_1': 'GABA-Glut',
#  'ACCCAAATCGTGACTA-1-VTA_1': 'GABA-Glut',
#  'ACCCAAATCTTTCAGT-1-VTA_1': 'GABA-Glut',
#  'ACCCTCAAGGTCTACT-1-VTA_1': 'Glut',
#  'ACCCTCACAAGCCCAC-1-VTA_1': 'GABA-Glut',
#  'ACCCTCACACATACTG-1-VTA_1': 'Dopa',
#  'ACCCTCACAGTGTGCC-1-VTA_1': 'GABA-Glut',
#  'ACCCTCATCATTCGTT-1-VTA_1': 'GABA',
#  'ACCCTTGCACGAAGAC-1-VTA_1': 'Dopa',
#  'ACCCTTGTCAGGTAAA-1-VTA_1': 'GABA',
#  'ACCGTTCAGCAATTAG-1-VTA_1': 'GABA-Glut',
#  'ACCGTTCAGCGAAACC-1-VTA_1': 'GABA-Glut',
#  'ACCGTTCCACCTCGTT-1-VTA_1': 'Glut',
#  'ACCGTTCTCCTTCGAC-1-VTA_1': 'Dopa',
#  'ACCGTTCTCGGCTTGG-1-VTA_1': 'Dopa',
#  'ACCTACCAGTGGACTG-1-VTA_1': 'GABA-Glut',
#  'ACCTACCGTTATGACC-1-VTA_1': 'Dopa',
#  'ACCTGAAAGAAGCGCT-1-VTA_1': 'GABA-Glut',
#  'ACCTGAAGTATGACAA-1-VTA_1': 'Dopa',
#  'ACCTGAAGTCTGTTAG-1-VTA_1': 'Non-neuron',
#  'ACCTGAAGTGTGAGCA-1-VTA_1': 'GABA',
#  'ACCTGTCAGGGCAGTT-1-VTA_1': 'Non-neuron',
#  'ACCTGTCGTCGGCACT-1-VTA_1': 'Dopa',
#  'ACCTGTCTCACCCATC-1-VTA_1': 'Dopa',
#  'ACCTGTCTCAGGACAG-1-VTA_1': 'Non-neuron',
#  'ACCTGTCTCTCAGTCC-1-VTA_1': 'Non-neuron',
#  'ACGATCAAGCGAAACC-1-VTA_1': 'GABA',
#  'ACGATCACAGCTCGGT-1-VTA_1': 'GABA-Glut',
#  'ACGATCACATTGCCGG-1-VTA_1': 'Dopa',
#  'ACGATCAGTCGATTAC-1-VTA_1': 'Dopa',
#  'ACGATCATCCGCGATG-1-VTA_1': 'GABA-Glut',
#  'ACGATGTTCACTACTT-1-VTA_1': 'Dopa',
#  'ACGATGTTCTCGTGGG-1-VTA_1': 'Dopa',
#  'ACGCACGAGGTGTGAC-1-VTA_1': 'GABA-Glut',
#  'ACGCACGAGGTTTACC-1-VTA_1': 'Non-neuron',
#  'ACGCACGCAATGCAAA-1-VTA_1': 'Glut',
#  'ACGCACGGTATGCTTG-1-VTA_1': 'GABA-Glut',
#  'ACGGAAGCAGATCACT-1-VTA_1': 'Dopa',
#  'ACGGAAGGTGTCCACG-1-VTA_1': 'GABA',
#  'ACGGAAGGTTTGGGAG-1-VTA_1': 'GABA-Glut',
#  'ACGGAAGTCATCTACT-1-VTA_1': 'Non-neuron',
#  'ACGGAAGTCCGTGACG-1-VTA_1': 'Glut',
#  'ACGGGTCAGCTGTACT-1-VTA_1': 'GABA-Glut',
#  'ACGGGTCCATTGCTTT-1-VTA_1': 'Glut',
#  'ACGGTCGAGGAGAGGC-1-VTA_1': 'Non-neuron',
#  'ACGGTCGAGTTCTCTT-1-VTA_1': 'GABA',
#  'ACGGTCGGTATTTCCT-1-VTA_1': 'Dopa',
#  'ACGGTCGTCACGAGGA-1-VTA_1': 'Glut',
#  'ACGGTTAAGGTGCGAT-1-VTA_1': 'Dopa',
#  'ACGGTTAAGGTTTACC-1-VTA_1': 'Glut-Sero',
#  'ACGGTTAGTAGATTAG-1-VTA_1': 'GABA-Glut',
#  'ACGGTTAGTGACACAG-1-VTA_1': 'GABA',
#  'ACGGTTATCTAACGGT-1-VTA_1': 'Glut',
#  'ACGTAACAGCTCTATG-1-VTA_1': 'GABA',
#  'ACGTAACAGGGTTAAT-1-VTA_1': 'GABA',
#  'ACGTAACCAGAGTGAC-1-VTA_1': 'Glut',
#  'ACGTAACTCAACGTGT-1-VTA_1': 'GABA-Glut',
#  'ACGTAACTCCTTTAGT-1-VTA_1': 'GABA-Glut',
#  'ACGTAACTCTAGGCAT-1-VTA_1': 'Dopa',
#  'ACGTACAAGGTAAGTT-1-VTA_1': 'GABA',
#  'ACGTACACAGCACACC-1-VTA_1': 'GABA',
#  'ACGTACAGTGGTCTAT-1-VTA_1': 'GABA',
#  'ACGTAGTAGCCTGTCG-1-VTA_1': 'GABA',
#  'ACGTAGTAGCGCTGCT-1-VTA_1': 'Glut',
#  'ACGTAGTCACAGCCTG-1-VTA_1': 'GABA-Glut',
#  'ACGTAGTCAGGTGAGT-1-VTA_1': 'GABA-Glut',
#  'ACGTAGTTCTATCCAT-1-VTA_1': 'Glut',
#  'ACGTAGTTCTATGCCC-1-VTA_1': 'GABA-Glut',
#  'ACGTCCTAGGTCCGAA-1-VTA_1': 'GABA',
#  'ACGTCCTAGGTCCTGC-1-VTA_1': 'GABA-Glut',
#  'ACGTCCTCAAACACCT-1-VTA_1': 'GABA',
#  'ACGTCCTCAATAACCC-1-VTA_1': 'Dopa',
#  'ACGTCCTGTCCCACGA-1-VTA_1': 'GABA',
#  'ACGTCCTTCCGATAGT-1-VTA_1': 'Dopa',
#  'ACGTTCCAGTGAACAT-1-VTA_1': 'Glut',
#  'ACGTTCCGTACAACGG-1-VTA_1': 'Non-neuron',
#  'ACTACGAAGACAACAT-1-VTA_1': 'Dopa',
#  'ACTACGAAGAGGATGA-1-VTA_1': 'GABA-Glut',
#  'ACTACGAAGATCACTC-1-VTA_1': 'Glut',
#  'ACTACGAAGTCGAAAT-1-VTA_1': 'Glut-Sero',
#  'ACTACGATCTGCGTCT-1-VTA_1': 'Glut-Sero',
#  'ACTACGATCTTAGCAG-1-VTA_1': 'GABA-Glut',
#  'ACTATCTAGAGTCGAC-1-VTA_1': 'GABA-Glut',
#  'ACTATCTTCTTGAACG-1-VTA_1': 'GABA',
#  'ACTATGGCATCCTCAC-1-VTA_1': 'GABA-Glut',
#  'ACTATGGCATTCTCTA-1-VTA_1': 'GABA',
#  'ACTATGGGTAGAGCTG-1-VTA_1': 'GABA',
#  'ACTATGGGTGTGAGCA-1-VTA_1': 'Glut',
#  'ACTATGGTCAAACCTG-1-VTA_1': 'GABA-Glut',
#  'ACTATTCCAATGTCTG-1-VTA_1': 'GABA',
#  'ACTATTCGTCCAGTTA-1-VTA_1': 'GABA-Glut',
#  'ACTATTCGTTTGGAGG-1-VTA_1': 'GABA',
#  'ACTCCCAAGGACGCAT-1-VTA_1': 'GABA-Glut',
#  'ACTCCCAAGGTAGATT-1-VTA_1': 'Dopa',
#  'ACTCCCACAAACGGCA-1-VTA_1': 'Dopa',
#  'ACTCCCACAAATACGA-1-VTA_1': 'GABA-Glut',
#  'ACTCCCACAGGCGTTC-1-VTA_1': 'GABA',
#  'ACTCCCACATACCAGT-1-VTA_1': 'Glut',
#  'ACTCTCGCAGGTCCCA-1-VTA_1': 'Dopa',
#  'ACTCTCGTCAAGAGGC-1-VTA_1': 'GABA',
#  'ACTCTCGTCGCCCAGA-1-VTA_1': 'GABA-Glut',
#  'ACTGATGAGCACTGGA-1-VTA_1': 'Glut-Sero',
#  'ACTGATGCAAATCCCA-1-VTA_1': 'Non-neuron',
#  'ACTGATGCAACGATCT-1-VTA_1': 'GABA',
#  'ACTGATGGTGCCTGCA-1-VTA_1': 'GABA',
#  'ACTGATGTCCAGCACG-1-VTA_1': 'Dopa',
#  'ACTGATGTCCTGCTAC-1-VTA_1': 'GABA',
#  'ACTGCAAAGTAAACTG-1-VTA_1': 'Non-neuron',
#  'ACTGCAACAAGCGATG-1-VTA_1': 'Non-neuron',
#  'ACTGCAACAGTAGGAC-1-VTA_1': 'Non-neuron',
#  'ACTGCAACATACAGGG-1-VTA_1': 'GABA-Glut',
#  'ACTGCAAGTCGATGCC-1-VTA_1': 'Dopa',
#  'ACTGCAATCACTCCGT-1-VTA_1': 'GABA-Glut',
#  'ACTGCAATCGGCGATC-1-VTA_1': 'GABA-Glut',
#  'ACTGTCCAGTCTTGGT-1-VTA_1': 'GABA-Glut',
#  'ACTGTCCGTACCTATG-1-VTA_1': 'Non-neuron',
#  'ACTGTCCGTCTGTCCT-1-VTA_1': 'Dopa',
#  'ACTGTCCTCTTCCACG-1-VTA_1': 'GABA',
#  'ACTGTGAAGCCGCTTG-1-VTA_1': 'GABA-Glut',
#  'ACTGTGAGTGGATCAG-1-VTA_1': 'Glut',
#  'ACTGTGAGTTCCCAAA-1-VTA_1': 'Non-neuron',
#  'ACTGTGAGTTTATGCG-1-VTA_1': 'GABA-Glut',
#  'ACTGTGAGTTTGGAGG-1-VTA_1': 'GABA-Glut',
#  'ACTGTGATCATTACGG-1-VTA_1': 'GABA',
#  'ACTGTGATCTGGAAGG-1-VTA_1': 'Non-neuron',
#  'ACTTAGGAGTGGATTA-1-VTA_1': 'GABA',
#  'ACTTAGGCACTGGCGT-1-VTA_1': 'GABA',
#  'ACTTAGGTCTAATTCC-1-VTA_1': 'GABA-Glut',
#  'ACTTATCAGGTAGCCA-1-VTA_1': 'GABA-Glut',
#  'ACTTATCAGTTGCTGT-1-VTA_1': 'Glut',
#  'ACTTATCCAAACACGG-1-VTA_1': 'Dopa',
#  'ACTTATCCAGAAGCTG-1-VTA_1': 'Glut',
#  'ACTTATCCAGAGTCTT-1-VTA_1': 'Dopa',
#  'ACTTATCGTGACTGTT-1-VTA_1': 'Glut-Sero',
#  'ACTTATCGTTGCTCCT-1-VTA_1': 'Glut',
#  'ACTTATCTCCCTTTGG-1-VTA_1': 'GABA-Glut',
#  'ACTTATCTCCGGTAAT-1-VTA_1': 'Dopa',
#  'ACTTCCGAGCCTTCTC-1-VTA_1': 'Non-neuron',
#  'ACTTCCGGTATCCCTC-1-VTA_1': 'GABA-Glut',
#  'ACTTCCGGTGAATGAT-1-VTA_1': 'GABA-Glut',
#  'ACTTCCGGTGGACTAG-1-VTA_1': 'GABA',
#  'ACTTCCGGTGGAGAAA-1-VTA_1': 'Dopa',
#  'ACTTCCGTCTGTGCTC-1-VTA_1': 'GABA',
#  'ACTTCCGTCTTTGCTA-1-VTA_1': 'GABA-Glut',
#  'ACTTCGCAGAGATCGC-1-VTA_1': 'Non-neuron',
#  'ACTTCGCCATACTTTC-1-VTA_1': 'GABA-Glut',
#  'ACTTCGCGTAGGATAT-1-VTA_1': 'Glut',
#  'ACTTCGCGTCGCAGTC-1-VTA_1': 'Glut',
#  'ACTTTCAAGTTAACGA-1-VTA_1': 'Non-neuron',
#  'ACTTTCACAAATAGCA-1-VTA_1': 'Dopa',
#  'ACTTTCACAACCCGCA-1-VTA_1': 'GABA-Glut',
#  'ACTTTCAGTTAGAAAC-1-VTA_1': 'GABA-Glut',
#  'ACTTTCATCTGAATGC-1-VTA_1': 'GABA-Glut',
#  'ACTTTCATCTTGATTC-1-VTA_1': 'GABA-Glut',
#  'ACTTTGTAGGACTGGT-1-VTA_1': 'Glut',
#  'ACTTTGTAGGTAGTAT-1-VTA_1': 'GABA',
#  'ACTTTGTAGGTTGAGC-1-VTA_1': 'GABA-Glut',
#  'ACTTTGTCAATAACGA-1-VTA_1': 'GABA-Glut',
#  'ACTTTGTCACTGGCGT-1-VTA_1': 'GABA-Glut',
#  'ACTTTGTCAGGTGACA-1-VTA_1': 'GABA',
#  'ACTTTGTGTCCCAAAT-1-VTA_1': 'Glut',
#  'ACTTTGTGTGAGTGAC-1-VTA_1': 'GABA',
#  'AGAAATGAGCATGGGT-1-VTA_1': 'Non-neuron',
#  'AGAAATGAGCTGTGCC-1-VTA_1': 'GABA-Glut',
#  'AGAAATGAGGATGAGA-1-VTA_1': 'Dopa',
#  'AGAAATGAGTCAACAA-1-VTA_1': 'GABA-Glut',
#  'AGAAATGCATCCGGTG-1-VTA_1': 'GABA',
#  'AGAAATGTCACAAGGG-1-VTA_1': 'GABA-Glut',
#  'AGAAATGTCGTCTAAG-1-VTA_1': 'GABA-Glut',
#  'AGAACAAAGCAGCCCT-1-VTA_1': 'Non-neuron',
#  'AGAACAAGTACATTGC-1-VTA_1': 'GABA-Glut',
#  'AGAACAAGTCGCTTAA-1-VTA_1': 'GABA',
#  'AGAACAATCCGACGGT-1-VTA_1': 'GABA',
#  'AGAACAATCCGAGTGC-1-VTA_1': 'Dopa',
#  'AGAACCTAGCCTCGTG-1-VTA_1': 'GABA-Glut',
#  'AGAACCTAGTGAGGTC-1-VTA_1': 'Glut',
#  'AGAACCTCAGTAGAGC-1-VTA_1': 'Glut-Sero',
#  'AGAACCTCAGTCGCTG-1-VTA_1': 'GABA',
#  'AGAACCTCATAAGCGG-1-VTA_1': 'GABA',
#  'AGAACCTCATGAAGGC-1-VTA_1': 'Non-neuron',
#  'AGAACCTGTCCTTTGC-1-VTA_1': 'GABA-Glut',
#  'AGAACCTGTCGCGGTT-1-VTA_1': 'GABA-Glut',
#  'AGAACCTTCATCCCGT-1-VTA_1': 'Glut',
#  'AGAACCTTCCGAGCTG-1-VTA_1': 'GABA',
#  'AGAACCTTCGAGAACG-1-VTA_1': 'Glut',
#  'AGAAGCGAGAGCAGAA-1-VTA_1': 'Dopa',
#  'AGAAGCGCATATGAAG-1-VTA_1': 'GABA',
#  'AGAAGCGGTTTAAGGA-1-VTA_1': 'GABA',
#  'AGAAGCGTCATGCGGC-1-VTA_1': 'Dopa',
#  'AGAAGCGTCCTGCCAT-1-VTA_1': 'GABA',
#  'AGAAGTAGTACTGCGC-1-VTA_1': 'Non-neuron',
#  'AGAAGTAGTGACAGCA-1-VTA_1': 'GABA-Glut',
#  'AGAAGTATCGCCGTGA-1-VTA_1': 'GABA-Glut',
#  'AGAAGTATCGGCAGTC-1-VTA_1': 'Non-neuron',
#  'AGACAAACACAACCGC-1-VTA_1': 'GABA-Glut',
#  'AGACAAACACAGCCAC-1-VTA_1': 'Non-neuron',
#  'AGACAAACAGACCTAT-1-VTA_1': 'GABA-Glut',
#  'AGACAAAGTATTGACC-1-VTA_1': 'GABA-Glut',
#  'AGACAAAGTCATCAGT-1-VTA_1': 'GABA-Glut',
#  'AGACAAATCTACCACC-1-VTA_1': 'Dopa',
#  'AGACAAATCTCCTGTG-1-VTA_1': 'GABA-Glut',
#  'AGACACTCACGAGGAT-1-VTA_1': 'GABA-Glut',
#  'AGACACTCATGAGAAT-1-VTA_1': 'Glut',
#  'AGACACTTCAACTCTT-1-VTA_1': 'Dopa',
#  'AGACAGGCAAACAGGC-1-VTA_1': 'Non-neuron',
#  'AGACAGGCAGACACAG-1-VTA_1': 'GABA-Glut',
#  'AGACAGGCAGCGAACA-1-VTA_1': 'GABA',
#  'AGACAGGCATCGGATT-1-VTA_1': 'GABA',
#  'AGACAGGGTAGGACTG-1-VTA_1': 'Glut',
#  'AGACAGGGTCCGTTTC-1-VTA_1': 'Dopa',
#  'AGACAGGTCTCACGAA-1-VTA_1': 'Non-neuron',
#  'AGACCATAGCATGCAG-1-VTA_1': 'GABA',
#  'AGACCATAGCTAGCCC-1-VTA_1': 'GABA-Glut',
#  'AGACCATAGTCAAGCG-1-VTA_1': 'GABA-Glut',
#  'AGACCATCACGCGGTT-1-VTA_1': 'Dopa',
#  'AGACCATGTTATGACC-1-VTA_1': 'GABA-Glut',
#  'AGACCATGTTCAAAGA-1-VTA_1': 'GABA-Glut',
#  'AGACCATTCATGCCCT-1-VTA_1': 'Non-neuron',
#  'AGACCATTCTCACGAA-1-VTA_1': 'GABA-Glut',
#  'AGACCCGCACCTAAAC-1-VTA_1': 'Dopa',
#  'AGACCCGCATCGCTCT-1-VTA_1': 'GABA',
#  'AGACCCGGTCAGATTC-1-VTA_1': 'Glut',
#  'AGACCCGTCGTCGACG-1-VTA_1': 'Glut',
#  'AGACTCACACGTAGAG-1-VTA_1': 'Glut',
#  'AGACTCAGTCGAAGCA-1-VTA_1': 'Glut',
#  'AGAGAATAGTCCTGCG-1-VTA_1': 'GABA-Glut',
#  'AGAGAATTCAACTACG-1-VTA_1': 'GABA',
#  'AGAGAATTCAGTGCGC-1-VTA_1': 'GABA',
#  'AGAGAATTCCGCGGAT-1-VTA_1': 'GABA',
#  'AGAGAGCAGCTTTGTG-1-VTA_1': 'GABA-Glut',
#  'AGAGAGCAGTTAGAAC-1-VTA_1': 'GABA-Glut',
#  'AGAGAGCTCGCAGATT-1-VTA_1': 'Glut-Sero',
#  'AGAGCAGGTACCTTCC-1-VTA_1': 'GABA-Glut',
#  'AGAGCAGTCACCGGGT-1-VTA_1': 'Glut',
#  'AGAGCAGTCCTCCACA-1-VTA_1': 'GABA',
#  'AGAGCCCAGTTGTAGA-1-VTA_1': 'Non-neuron',
#  'AGAGCCCCAGAGACTG-1-VTA_1': 'GABA-Glut',
#  'AGAGCCCTCCACATAG-1-VTA_1': 'GABA-Glut',
#  'AGAGCCCTCCGTGTAA-1-VTA_1': 'GABA',
#  'AGATAGAAGATTCGCT-1-VTA_1': 'GABA-Glut',
#  'AGATAGAAGGAGGGTG-1-VTA_1': 'Glut',
#  'AGATAGAAGGGTTGCA-1-VTA_1': 'Dopa',
#  'AGATAGACACTAGTAC-1-VTA_1': 'GABA',
#  'AGATAGACACTATCCC-1-VTA_1': 'Non-neuron',
#  'AGATAGAGTAGACACG-1-VTA_1': 'GABA-Glut',
#  'AGATAGAGTGGCCCAT-1-VTA_1': 'GABA-Glut',
#  'AGATAGATCGGCTGGT-1-VTA_1': 'GABA',
#  'AGATCCAAGCTGGTGA-1-VTA_1': 'GABA',
#  'AGATCCAAGGAAAGGT-1-VTA_1': 'Dopa',
#  'AGATCCACATATGCGT-1-VTA_1': 'GABA-Glut',
#  'AGATCGTAGACAGTCG-1-VTA_1': 'Dopa',
#  'AGATCGTAGATTGAGT-1-VTA_1': 'Glut',
#  'AGATCGTAGGCATGGT-1-VTA_1': 'Dopa',
#  'AGATCGTAGTATGATG-1-VTA_1': 'Glut-Sero',
#  'AGATCGTCAAAGTATG-1-VTA_1': 'Dopa',
#  'AGATCGTCACATTACG-1-VTA_1': 'Dopa',
#  'AGATCGTGTCCTTAAG-1-VTA_1': 'GABA',
#  'AGATGAAAGCATATGA-1-VTA_1': 'GABA-Glut',
#  'AGATGAAAGCGCCTAC-1-VTA_1': 'GABA',
#  'AGATGAAAGGCGCTCT-1-VTA_1': 'GABA-Glut',
#  'AGATGAACAACACAAA-1-VTA_1': 'Glut',
#  'AGATGAACAGCTGGTC-1-VTA_1': 'GABA',
#  'AGATGAATCTTGTTAC-1-VTA_1': 'GABA-Glut',
#  'AGATGCTCAGACCTAT-1-VTA_1': 'Glut',
#  'AGATGCTCAGTGGCTC-1-VTA_1': 'GABA-Glut',
#  'AGATGCTCATGTTACG-1-VTA_1': 'GABA-Glut',
#  'AGATGCTGTCAACGCC-1-VTA_1': 'GABA-Glut',
#  'AGATGCTGTCAGACGA-1-VTA_1': 'GABA-Glut',
#  'AGATGCTTCGAACCAT-1-VTA_1': 'GABA',
#  'AGATGCTTCGATTGGT-1-VTA_1': 'GABA-Glut',
#  'AGATGCTTCTCCCTAG-1-VTA_1': 'Glut',
#  'AGCATCAAGCGCTGCT-1-VTA_1': 'Glut',
#  'AGCATCAAGGCGTTGA-1-VTA_1': 'GABA-Glut',
#  'AGCATCACAGCTGTCG-1-VTA_1': 'Glut-Sero',
#  'AGCATCACATGCCATA-1-VTA_1': 'GABA-Glut',
#  'AGCATCATCAGCGCAC-1-VTA_1': 'Glut',
#  'AGCATCATCCGCTGTT-1-VTA_1': 'Dopa',
#  'AGCCAATAGCGATCGA-1-VTA_1': 'GABA',
#  'AGCCAATGTCTCAGAT-1-VTA_1': 'Dopa',
#  'AGCCAATGTGATACCT-1-VTA_1': 'GABA-Glut',
#  'AGCCAATTCATACGGT-1-VTA_1': 'Dopa',
#  'AGCCACGAGAAAGTCT-1-VTA_1': 'GABA-Glut',
#  'AGCCACGCAATGAGCG-1-VTA_1': 'Glut',
#  'AGCCACGCAATTCTTC-1-VTA_1': 'Glut',
#  'AGCCACGTCCGCTAGG-1-VTA_1': 'Dopa',
#  'AGCCAGCAGTGAACAT-1-VTA_1': 'Glut-Sero',
#  'AGCCAGCGTGATACTC-1-VTA_1': 'Glut',
#  'AGCCAGCGTGATTGGG-1-VTA_1': 'Glut',
#  'AGCCAGCTCAGCTGAT-1-VTA_1': 'Dopa',
#  'AGCGATTAGAGTGTGC-1-VTA_1': 'GABA-Glut',
#  'AGCGATTAGATCACTC-1-VTA_1': 'GABA',
#  'AGCGATTAGATTACCC-1-VTA_1': 'Dopa',
#  'AGCGATTCATTGAAGA-1-VTA_1': 'Glut',
#  'AGCGCCAGTCGGCACT-1-VTA_1': 'GABA-Glut',
#  'AGCGCCATCTCGTTTA-1-VTA_1': 'Dopa',
#  'AGCGCTGAGGGAGATA-1-VTA_1': 'GABA-Glut',
#  'AGCGCTGCACATGACT-1-VTA_1': 'GABA',
#  'AGCGCTGCAGAGCTAG-1-VTA_1': 'GABA-Glut',
#  'AGCGCTGGTGGAAATT-1-VTA_1': 'GABA',
#  'AGCGTATAGCGACTGA-1-VTA_1': 'GABA-Glut',
#  'AGCGTATGTCTCAGAT-1-VTA_1': 'GABA-Glut',
#  'AGCGTATTCGAACGCC-1-VTA_1': 'Glut',
#  'AGCGTATTCTGTAACG-1-VTA_1': 'Dopa',
#  'AGCTACAAGGTAGTCG-1-VTA_1': 'GABA-Glut',
#  'AGCTACACATATCTGG-1-VTA_1': 'Non-neuron',
#  'AGCTACAGTGATTAGA-1-VTA_1': 'GABA',
#  'AGCTACATCAGAGCGA-1-VTA_1': 'Glut',
#  'AGCTACATCCTGGTCT-1-VTA_1': 'GABA-Glut',
#  'AGCTACATCCTGTTGC-1-VTA_1': 'GABA',
#  'AGCTACATCTACTTCA-1-VTA_1': 'GABA-Glut',
#  'AGCTACATCTCAGGCG-1-VTA_1': 'Glut',
#  'AGCTACATCTTTGCAT-1-VTA_1': 'GABA-Glut',
#  'AGCTCAAAGTCTACCA-1-VTA_1': 'GABA-Glut',
#  'AGCTCAACACCTTCGT-1-VTA_1': 'GABA-Glut',
#  'AGCTCAAGTCTTCGAA-1-VTA_1': 'GABA-Glut',
#  'AGCTCAATCCGTAATG-1-VTA_1': 'GABA-Glut',
#  'AGCTTCCAGGGACCAT-1-VTA_1': 'GABA-Glut',
#  'AGCTTCCGTAGGAAAG-1-VTA_1': 'Non-neuron',
#  'AGCTTCCTCCGCAACG-1-VTA_1': 'GABA-Glut',
#  'AGGAAATAGAGAAGGT-1-VTA_1': 'GABA-Glut',
#  'AGGAAATAGCCTCATA-1-VTA_1': 'Dopa',
#  'AGGAAATAGGATTTAG-1-VTA_1': 'GABA-Glut',
#  'AGGAAATCAGCGTGAA-1-VTA_1': 'GABA-Glut',
#  'AGGAAATGTATCACCA-1-VTA_1': 'GABA',
#  'AGGAAATTCTCGGCTT-1-VTA_1': 'Dopa',
#  'AGGAATAAGAGAGTTT-1-VTA_1': 'Dopa',
#  'AGGAATAAGCGCTTCG-1-VTA_1': 'Glut-Sero',
#  'AGGAATAAGTAGATCA-1-VTA_1': 'GABA',
#  'AGGAATAAGTCTTCCC-1-VTA_1': 'Non-neuron',
#  'AGGAATACATGGCCCA-1-VTA_1': 'Dopa',
#  'AGGAATAGTAGTCCTA-1-VTA_1': 'GABA-Glut',
#  'AGGAATAGTGTTTCTT-1-VTA_1': 'GABA-Glut',
#  'AGGAATAGTTCTCCTG-1-VTA_1': 'GABA',
#  'AGGAATATCCGTTGAA-1-VTA_1': 'GABA',
#  'AGGACGAAGAAACTCA-1-VTA_1': 'Glut',
#  'AGGACGAAGCTAGATA-1-VTA_1': 'GABA-Glut',
#  'AGGACGACACAGCCAC-1-VTA_1': 'GABA',
#  'AGGACGAGTAGGTCAG-1-VTA_1': 'Dopa',
#  'AGGACGAGTCAGTTTG-1-VTA_1': 'GABA-Glut',
#  'AGGACGATCCCGAAAT-1-VTA_1': 'Non-neuron',
#  'AGGACGATCCTCACTG-1-VTA_1': 'GABA-Glut',
#  'AGGACTTAGGTCATTC-1-VTA_1': 'GABA-Glut',
#  'AGGACTTCAGAAACCG-1-VTA_1': 'Dopa',
#  'AGGACTTGTAGCTTGT-1-VTA_1': 'GABA',
#  'AGGACTTTCACATACG-1-VTA_1': 'GABA',
#  'AGGACTTTCATTCGTT-1-VTA_1': 'GABA-Glut',
#  'AGGACTTTCCTATTGT-1-VTA_1': 'GABA-Glut',
#  'AGGACTTTCGTGCGAC-1-VTA_1': 'Glut',
#  'AGGACTTTCTATACGG-1-VTA_1': 'Dopa',
#  'AGGAGGTAGCTAATCC-1-VTA_1': 'Dopa',
#  'AGGAGGTAGGCGCTTC-1-VTA_1': 'GABA-Glut',
#  'AGGAGGTAGTATCTGC-1-VTA_1': 'GABA',
#  'AGGAGGTAGTGACACG-1-VTA_1': 'GABA-Glut',
#  'AGGAGGTCAGGTATGG-1-VTA_1': 'GABA-Glut',
#  'AGGAGGTGTATGTGTC-1-VTA_1': 'Glut',
#  'AGGAGGTGTCTGTGTA-1-VTA_1': 'GABA-Glut',
#  'AGGAGGTGTTTCGTTT-1-VTA_1': 'GABA-Glut',
#  'AGGAGGTTCTACAGGT-1-VTA_1': 'Non-neuron',
#  'AGGATAAAGTATGGCG-1-VTA_1': 'GABA-Glut',
#  'AGGATAACAGACCAGA-1-VTA_1': 'GABA-Glut',
#  'AGGATAACATGTTTGG-1-VTA_1': 'Glut',
#  'AGGATAAGTGATAGAT-1-VTA_1': 'Glut',
#  'AGGATAAGTGTGCCTG-1-VTA_1': 'GABA',
#  'AGGATAAGTTTGCAGT-1-VTA_1': 'GABA-Glut',
#  'AGGATCTCAACTCATG-1-VTA_1': 'GABA-Glut',
#  'AGGATCTGTGGCAGAT-1-VTA_1': 'GABA-Glut',
#  'AGGATCTTCACGATAC-1-VTA_1': 'GABA-Glut',
#  'AGGATCTTCCCGAAAT-1-VTA_1': 'GABA-Glut',
#  'AGGCATTAGAATAGTC-1-VTA_1': 'Non-neuron',
#  'AGGCATTTCCTAAGTG-1-VTA_1': 'Dopa',
#  'AGGCATTTCTAGCAAC-1-VTA_1': 'GABA-Glut',
#  'AGGCCACGTAGAGATT-1-VTA_1': 'GABA-Glut',
#  'AGGCCACGTGATACTC-1-VTA_1': 'GABA-Glut',
#  'AGGCCACTCTAGTTCT-1-VTA_1': 'Dopa',
#  'AGGCTGCCACAAATCC-1-VTA_1': 'GABA',
#  'AGGCTGCCAGACACCC-1-VTA_1': 'GABA-Glut',
#  'AGGCTGCCATGGTGGA-1-VTA_1': 'Glut',
#  'AGGCTGCGTTAGGGAC-1-VTA_1': 'GABA-Glut',
#  'AGGCTGCTCCCATTCG-1-VTA_1': 'GABA',
#  'AGGGAGTAGACGGTTG-1-VTA_1': 'GABA-Glut',
#  'AGGGAGTAGGCTTAGG-1-VTA_1': 'GABA',
#  'AGGGAGTAGTTTAGGA-1-VTA_1': 'GABA-Glut',
#  'AGGGAGTCAGACTCTA-1-VTA_1': 'Dopa',
#  'AGGGAGTGTCTCAGAT-1-VTA_1': 'GABA-Glut',
#  'AGGGAGTGTTCAAACC-1-VTA_1': 'GABA-Glut',
#  'AGGGAGTGTTGCTCCT-1-VTA_1': 'GABA-Glut',
#  'AGGGAGTTCTCATAGG-1-VTA_1': 'Glut',
#  'AGGGCCTAGAATTTGG-1-VTA_1': 'GABA',
#  'AGGGCCTAGGCTGAAC-1-VTA_1': 'GABA-Glut',
#  'AGGGCCTAGTCGTTAC-1-VTA_1': 'GABA',
#  'AGGGCCTGTTGAAGTA-1-VTA_1': 'GABA-Glut',
#  'AGGGCCTTCACCGCTT-1-VTA_1': 'GABA-Glut',
#  'AGGGCCTTCACTTCTA-1-VTA_1': 'Glut-Sero',
#  'AGGGCCTTCCTGCCAT-1-VTA_1': 'Glut-Sero',
#  'AGGGCTCAGTTTCTTC-1-VTA_1': 'GABA-Glut',
#  'AGGGCTCTCACTACGA-1-VTA_1': 'GABA-Glut',
#  'AGGGCTCTCAGTAGGG-1-VTA_1': 'GABA-Glut',
#  'AGGGCTCTCGCTACAA-1-VTA_1': 'GABA',
#  'AGGGTCCAGAGCCTGA-1-VTA_1': 'Glut',
#  'AGGGTCCAGCCATTCA-1-VTA_1': 'Dopa',
#  'AGGGTCCGTTCGGGTC-1-VTA_1': 'GABA',
#  'AGGGTCCTCAGGGATG-1-VTA_1': 'Dopa',
#  'AGGGTCCTCTGGCCTT-1-VTA_1': 'GABA-Glut',
#  'AGGGTGAAGCGATGGT-1-VTA_1': 'Dopa',
#  'AGGGTGAAGCTTTGTG-1-VTA_1': 'GABA-Glut',
#  'AGGGTGAAGGAACTAT-1-VTA_1': 'Dopa',
#  'AGGGTGAAGTAGGTTA-1-VTA_1': 'GABA',
#  'AGGGTGAAGTGTTCCA-1-VTA_1': 'GABA-Glut',
#  'AGGGTGACAATAAGGT-1-VTA_1': 'Glut',
#  'AGGGTGAGTGTGTCGC-1-VTA_1': 'GABA-Glut',
#  'AGGGTGAGTTTCGTGA-1-VTA_1': 'Dopa',
#  'AGGGTTTAGAGTGAAG-1-VTA_1': 'GABA-Glut',
#  'AGGGTTTAGCTAGATA-1-VTA_1': 'GABA',
#  'AGGGTTTAGCTTCTAG-1-VTA_1': 'Glut',
#  'AGGGTTTAGGAATTAC-1-VTA_1': 'Glut',
#  'AGGGTTTGTTGGATCT-1-VTA_1': 'GABA',
#  'AGGGTTTTCACTACGA-1-VTA_1': 'GABA',
#  'AGGTAGGAGCGCCCAT-1-VTA_1': 'Dopa',
#  'AGGTAGGAGGGTCACA-1-VTA_1': 'GABA',
#  'AGGTAGGAGTTGAAAC-1-VTA_1': 'GABA-Glut',
#  'AGGTAGGCATGGCCAC-1-VTA_1': 'GABA-Glut',
#  'AGGTAGGGTAGCCAGA-1-VTA_1': 'GABA',
#  'AGGTAGGGTATCAGCT-1-VTA_1': 'Glut',
#  'AGGTAGGGTCTCGGGT-1-VTA_1': 'Glut',
#  'AGGTAGGTCAAACCCA-1-VTA_1': 'Glut-Sero',
#  'AGGTAGGTCCCATAGA-1-VTA_1': 'GABA-Glut',
#  'AGGTAGGTCGCACGAC-1-VTA_1': 'GABA-Glut',
#  'AGGTAGGTCTCATAGG-1-VTA_1': 'GABA-Glut',
#  'AGGTCATCACAAGCCC-1-VTA_1': 'Glut',
#  'AGGTCATGTCATCTAG-1-VTA_1': 'GABA',
#  'AGGTCATGTGCGGATA-1-VTA_1': 'GABA-Glut',
#  'AGGTCATGTTGCAACT-1-VTA_1': 'Dopa',
#  'AGGTCTAAGCGGTAAC-1-VTA_1': 'Glut',
#  'AGGTCTACAGGCCTGT-1-VTA_1': 'Glut-Sero',
#  'AGGTCTACATTCATCT-1-VTA_1': 'GABA-Glut',
#  'AGGTCTAGTACGCGTC-1-VTA_1': 'GABA-Glut',
#  'AGGTCTAGTTCATCGA-1-VTA_1': 'Glut',
#  'AGGTCTAGTTTACGAC-1-VTA_1': 'GABA-Glut',
#  'AGGTCTATCATGAGTC-1-VTA_1': 'GABA',
#  'AGGTCTATCGCCGATG-1-VTA_1': 'GABA-Glut',
#  'AGGTCTATCGCTATTT-1-VTA_1': 'GABA',
#  'AGGTGTTAGACGTCGA-1-VTA_1': 'GABA',
#  'AGGTGTTAGCGCCATC-1-VTA_1': 'GABA-Glut',
#  'AGGTGTTCAAGCGATG-1-VTA_1': 'GABA',
#  'AGGTGTTCAGAGCGTA-1-VTA_1': 'GABA',
#  'AGGTGTTCATGAAGCG-1-VTA_1': 'GABA-Glut',
#  'AGGTTACAGCCTCCAG-1-VTA_1': 'Glut',
#  'AGGTTACAGCTAAGTA-1-VTA_1': 'Non-neuron',
#  'AGGTTACAGGAGGTTC-1-VTA_1': 'GABA',
#  'AGGTTACAGGCTGGAT-1-VTA_1': 'Dopa',
#  'AGGTTACAGTAACGAT-1-VTA_1': 'Dopa',
#  'AGGTTGTAGATAGTGT-1-VTA_1': 'GABA-Glut',
#  'AGGTTGTCATGATCTG-1-VTA_1': 'Glut',
#  'AGGTTGTTCCATGAGT-1-VTA_1': 'GABA-Glut',
#  'AGGTTGTTCTTCCACG-1-VTA_1': 'Glut',
#  'AGTAACCAGGTAAGGA-1-VTA_1': 'Dopa',
#  'AGTAACCCACTTGGCG-1-VTA_1': 'GABA',
#  'AGTAACCTCGCACGGT-1-VTA_1': 'GABA',
#  'AGTACCATCCACGTGG-1-VTA_1': 'Glut',
#  'AGTACCATCGACACCG-1-VTA_1': 'GABA',
#  'AGTACTGAGAGAGAAC-1-VTA_1': 'GABA',
#  'AGTACTGCAACTTCTT-1-VTA_1': 'GABA-Glut',
#  'AGTACTGCAGATGCGA-1-VTA_1': 'Non-neuron',
#  'AGTACTGTCTCACTCG-1-VTA_1': 'GABA-Glut',
#  'AGTAGCTAGCACGTCC-1-VTA_1': 'GABA-Glut',
#  'AGTAGCTAGCGCCATC-1-VTA_1': 'GABA-Glut',
#  'AGTAGCTTCGTCTAAG-1-VTA_1': 'GABA-Glut',
#  'AGTAGTCCAGTAGAAT-1-VTA_1': 'GABA-Glut',
#  'AGTAGTCGTACAGGTG-1-VTA_1': 'Glut',
#  'AGTAGTCGTAGACAGC-1-VTA_1': 'Non-neuron',
#  'AGTAGTCGTCATCCCT-1-VTA_1': 'GABA',
#  'AGTAGTCGTTTACGAC-1-VTA_1': 'GABA',
#  'AGTAGTCTCGGAGATG-1-VTA_1': 'GABA-Glut',
#  'AGTCAACAGACTCGAG-1-VTA_1': 'Dopa',
#  'AGTCAACAGCACCGAA-1-VTA_1': 'Glut',
#  'AGTCAACTCCCGTGTT-1-VTA_1': 'Glut-Sero',
#  'AGTCACAAGAACTTCC-1-VTA_1': 'GABA-Glut',
#  'AGTCACAAGTGCGCTC-1-VTA_1': 'GABA-Glut',
#  'AGTCACACATTCCTAT-1-VTA_1': 'GABA-Glut',
#  'AGTCACAGTATGTCTG-1-VTA_1': 'Glut',
#  'AGTCACAGTGAGCCAA-1-VTA_1': 'Glut',
#  'AGTCACAGTTTAGTCG-1-VTA_1': 'GABA-Glut',
#  'AGTCACATCCATCACC-1-VTA_1': 'Non-neuron',
#  'AGTCACATCGGAACTT-1-VTA_1': 'Glut',
#  'AGTCATGAGTATCCTG-1-VTA_1': 'GABA',
#  'AGTCATGCAACTCCCT-1-VTA_1': 'GABA',
#  'AGTCATGCAACTTGCA-1-VTA_1': 'GABA-Glut',
#  'AGTCATGCACTCGATA-1-VTA_1': 'GABA',
#  'AGTCATGCAGAGGAAA-1-VTA_1': 'Dopa',
#  'AGTCATGGTAGACGGT-1-VTA_1': 'Non-neuron',
#  'AGTCATGTCCATTGGA-1-VTA_1': 'Dopa',
#  'AGTCTCCCACTATCGA-1-VTA_1': 'GABA-Glut',
#  'AGTCTCCCACTGTCCT-1-VTA_1': 'Glut',
#  'AGTCTCCCACTGTTCC-1-VTA_1': 'GABA',
#  'AGTCTCCCAGTGTATC-1-VTA_1': 'Glut',
#  'AGTCTCCCAGTGTGGA-1-VTA_1': 'Dopa',
#  'AGTCTCCCATCACGGC-1-VTA_1': 'GABA',
#  'AGTGACTGTTCTGAGT-1-VTA_1': 'Dopa',
#  'AGTGACTTCATTGTTC-1-VTA_1': 'Dopa',
#  'AGTGACTTCGGCCTTT-1-VTA_1': 'Glut',
#  'AGTGATCCATGACAGG-1-VTA_1': 'Dopa',
#  'AGTGCCGAGGTCACCC-1-VTA_1': 'GABA',
#  'AGTGCCGGTCCGTTTC-1-VTA_1': 'Glut',
#  'AGTGCCGGTTGGAGGT-1-VTA_1': 'Dopa',
#  'AGTGCCGTCGGCCAAC-1-VTA_1': 'GABA',
#  'AGTGCCGTCTGAGTCA-1-VTA_1': 'Glut',
#  'AGTGTTGAGAGCAGTC-1-VTA_1': 'GABA',
#  'AGTGTTGAGTGCACTT-1-VTA_1': 'GABA',
#  'AGTGTTGCAGGAAGTC-1-VTA_1': 'Dopa',
#  'AGTGTTGGTCACCTTC-1-VTA_1': 'GABA-Glut',
#  'AGTTAGCGTAACATAG-1-VTA_1': 'GABA-Glut',
#  'AGTTAGCTCAGTCACA-1-VTA_1': 'Dopa',
#  'AGTTAGCTCATGGTAC-1-VTA_1': 'GABA-Glut',
#  'AGTTAGCTCTCCGAGG-1-VTA_1': 'GABA-Glut',
#  'AGTTCCCAGCGACTTT-1-VTA_1': 'Dopa',
#  'AGTTCCCCAGACCATT-1-VTA_1': 'GABA-Glut',
#  'AGTTCCCTCAAAGAAC-1-VTA_1': 'GABA',
#  'AGTTCCCTCCGATCTC-1-VTA_1': 'GABA',
#  'AGTTCCCTCGCCAACG-1-VTA_1': 'GABA',
#  'AGTTCCCTCTCTTAAC-1-VTA_1': 'GABA',
#  'AGTTCGAAGAGCTTTC-1-VTA_1': 'GABA',
#  'ATACCGAAGAGCCGAT-1-VTA_1': 'Glut',
#  'ATACCGAAGGGTACGT-1-VTA_1': 'GABA-Glut',
#  'ATACCGAGTATCGCAT-1-VTA_1': 'Glut',
#  'ATACCGAGTGCGGTAA-1-VTA_1': 'Non-neuron',
#  'ATACCGAGTGTGAGCA-1-VTA_1': 'GABA',
#  'ATACCTTAGATGGGCT-1-VTA_1': 'GABA-Glut',
#  'ATACCTTAGTTGCCTA-1-VTA_1': 'Glut',
#  'ATACCTTGTGACAGCA-1-VTA_1': 'GABA',
#  'ATACCTTTCATGGATC-1-VTA_1': 'GABA',
#  'ATACTTCCAAGGTCGA-1-VTA_1': 'GABA',
#  'ATACTTCGTGCGTGCT-1-VTA_1': 'GABA-Glut',
#  'ATACTTCTCTGTGCGG-1-VTA_1': 'GABA-Glut',
#  'ATAGACCAGATGGTAT-1-VTA_1': 'GABA',
#  'ATAGACCAGGTTGGAC-1-VTA_1': 'GABA-Glut',
#  'ATAGACCCACTGCGAC-1-VTA_1': 'GABA',
#  'ATAGACCCAGACAAAT-1-VTA_1': 'Non-neuron',
#  'ATAGACCTCATCGTAG-1-VTA_1': 'GABA',
#  'ATAGACCTCGTCGATA-1-VTA_1': 'Dopa',
#  'ATAGACCTCTCAAAGC-1-VTA_1': 'GABA-Glut',
#  'ATAGACCTCTCATGCC-1-VTA_1': 'GABA',
#  'ATAGAGACACGGTGCT-1-VTA_1': 'Non-neuron',
#  'ATAGAGACATGAGTAA-1-VTA_1': 'GABA',
#  'ATAGAGAGTCACTCTC-1-VTA_1': 'Glut-Sero',
#  'ATAGAGAGTGGCATCC-1-VTA_1': 'Glut',
#  'ATAGAGAGTTTCTATC-1-VTA_1': 'Glut-Sero',
#  'ATAGAGATCTCAAAGC-1-VTA_1': 'Glut',
#  'ATAGGCTAGCTCTATG-1-VTA_1': 'GABA-Glut',
#  'ATAGGCTCATTGAAAG-1-VTA_1': 'Glut',
#  'ATAGGCTGTCGCATCG-1-VTA_1': 'Glut',
#  'ATAGGCTGTCTAACGT-1-VTA_1': 'Dopa',
#  'ATAGGCTTCGAGCTGC-1-VTA_1': 'GABA-Glut',
#  'ATATCCTAGAGCACTG-1-VTA_1': 'Non-neuron',
#  'ATATCCTCACCGTACG-1-VTA_1': 'Dopa',
#  'ATATCCTCAGACGGAT-1-VTA_1': 'GABA',
#  'ATATCCTCATATGCGT-1-VTA_1': 'GABA-Glut',
#  'ATATCCTGTTTCGGCG-1-VTA_1': 'GABA',
#  'ATCACAGCACCAACAT-1-VTA_1': 'Non-neuron',
#  'ATCACAGCAGCGTGAA-1-VTA_1': 'Glut-Sero',
#  'ATCACAGTCAACTCTT-1-VTA_1': 'Glut',
#  'ATCACGAAGGACATCG-1-VTA_1': 'GABA-Glut',
#  'ATCACGAGTATTGCCA-1-VTA_1': 'GABA',
#  'ATCACGAGTGAACTAA-1-VTA_1': 'GABA-Glut',
#  'ATCACGAGTGCTGATT-1-VTA_1': 'GABA-Glut',
#  'ATCACGATCTGGGCGT-1-VTA_1': 'GABA-Glut',
#  'ATCACTTGTTACCCAA-1-VTA_1': 'Glut',
#  'ATCACTTGTTGGGATG-1-VTA_1': 'Non-neuron',
#  'ATCACTTTCCCTTTGG-1-VTA_1': 'GABA-Glut',
#  'ATCACTTTCGTCAGAT-1-VTA_1': 'GABA-Glut',
#  'ATCAGGTAGCGCATCC-1-VTA_1': 'GABA',
#  'ATCAGGTTCAATCGGT-1-VTA_1': 'GABA-Glut',
#  'ATCAGGTTCATTCTTG-1-VTA_1': 'GABA',
#  'ATCATTCAGATACGAT-1-VTA_1': 'GABA',
#  'ATCATTCGTTATTCTC-1-VTA_1': 'GABA-Glut',
#  'ATCATTCTCCAGGACC-1-VTA_1': 'Non-neuron',
#  'ATCCACCAGCGCTGCT-1-VTA_1': 'Non-neuron',
#  'ATCCACCCAGCGGATA-1-VTA_1': 'GABA-Glut',
#  'ATCCACCCATCATTTC-1-VTA_1': 'GABA-Glut',
#  'ATCCACCGTTTACTTC-1-VTA_1': 'GABA-Glut',
#  'ATCCACCTCCTACACC-1-VTA_1': 'Non-neuron',
#  'ATCCACCTCCTGGTCT-1-VTA_1': 'GABA',
#  'ATCCATTTCAAAGAAC-1-VTA_1': 'Glut',
#  'ATCCATTTCACCTGGG-1-VTA_1': 'GABA-Glut',
#  'ATCCATTTCGCCACTT-1-VTA_1': 'Dopa',
#  'ATCCCTGGTGTCCCTT-1-VTA_1': 'Glut',
#  'ATCCCTGGTTCGGCGT-1-VTA_1': 'GABA-Glut',
#  'ATCCCTGTCGTCGGGT-1-VTA_1': 'GABA-Glut',
#  'ATCCCTGTCTAAGAAG-1-VTA_1': 'GABA-Glut',
#  'ATCCGTCCACCAATTG-1-VTA_1': 'GABA',
#  'ATCCGTCGTGCACGCT-1-VTA_1': 'Glut',
#  'ATCCGTCGTGCCCGTA-1-VTA_1': 'GABA',
#  'ATCCGTCGTGCGGTAA-1-VTA_1': 'GABA-Glut',
#  'ATCCGTCGTGTCCTAA-1-VTA_1': 'Non-neuron',
#  'ATCCGTCTCTTGGATG-1-VTA_1': 'Non-neuron',
#  'ATCCTATAGCGAGTCA-1-VTA_1': 'Dopa',
#  'ATCCTATAGTAGTCCT-1-VTA_1': 'Dopa',
#  'ATCCTATAGTTGTCAC-1-VTA_1': 'GABA-Glut',
#  'ATCCTATCATACCATG-1-VTA_1': 'GABA-Glut',
#  'ATCCTATGTTATGTGC-1-VTA_1': 'GABA',
#  'ATCCTATTCCAGCACG-1-VTA_1': 'Dopa',
#  'ATCGATGCAAATACGA-1-VTA_1': 'Glut-Sero',
#  'ATCGATGCAGCTACAT-1-VTA_1': 'Glut',
#  'ATCGATGCATGGTGGA-1-VTA_1': 'Dopa',
#  'ATCGATGGTTTAAGGA-1-VTA_1': 'Glut',
#  'ATCGATGTCCAACCAA-1-VTA_1': 'Glut',
#  'ATCGATGTCGTAGCCG-1-VTA_1': 'GABA',
#  'ATCGCCTCAAGTGGAC-1-VTA_1': 'Glut',
#  'ATCGCCTCACACCGAC-1-VTA_1': 'Dopa',
#  'ATCGGATAGATAGTCA-1-VTA_1': 'GABA',
#  'ATCGGATAGGTCACAG-1-VTA_1': 'GABA',
#  'ATCGGATCACATTACG-1-VTA_1': 'GABA-Glut',
#  'ATCGGATCAGAGTCTT-1-VTA_1': 'Non-neuron',
#  'ATCGGATCAGCACCCA-1-VTA_1': 'Non-neuron',
#  'ATCGGATGTTAAGTCC-1-VTA_1': 'Glut',
#  'ATCGGATTCCCAGGAC-1-VTA_1': 'Non-neuron',
#  'ATCGGATTCCGTGTAA-1-VTA_1': 'GABA',
#  'ATCGGCGAGCAAGCCA-1-VTA_1': 'Non-neuron',
#  ...}

# %%
Class_new = []
for i in range(adata.shape[0]):
    if adata.obs.index[i] in dic.keys():
        Class_new.append(dic[adata.obs.index[i]])
    else: 
        Class_new.append('Non-neuron')
adata.obs['Class_new'] = Class_new

# %%
adata.obs['Class_new']
# Out:
# AAACCCAAGACTGTTC-1-VTA_1     GABA-Glut
# AAACCCACATACCGTA-1-VTA_1    Non-neuron
# AAACCCAGTAACGCGA-1-VTA_1          Glut
# AAACCCAGTCACTAGT-1-VTA_1     GABA-Glut
# AAACGAAAGAGCATTA-1-VTA_1          Dopa
#                                ...
# TTTGTTGGTTCCCACT-1-VTA_2          Glut
# TTTGTTGGTTTAGACC-1-VTA_2    Non-neuron
# TTTGTTGTCACGAACT-1-VTA_2     GABA-Glut
# TTTGTTGTCAGAGCAG-1-VTA_2    Non-neuron
# TTTGTTGTCCTCTTTC-1-VTA_2          Glut
# Name: Class_new, Length: 23014, dtype: category
# Categories (6, object): ['Dopa', 'GABA', 'GABA-Glut', 'Glut', 'Glut-Sero', 'Non-neuron']

# %%
adata.write('VTA_allcell_merge_harmony.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 23014 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'Neuron', 'Sample', 'leiden_res_1.00', 'leiden_res_1.20', 'Neuron_merge', 'Class_new'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Neuron_colors', 'Neuron_merge_colors', 'Sample_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'dendrogram_leiden_res_1.20', 'dendrogram_leiden_res_1.50', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'neighbors', 'pca', 'umap', 'Class_new_colors'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(
    adata,
    color="Class_new",
    legend_fontsize=8,save = 'allcell_merge_class_new.pdf',palette= 'Set2'
)
# Out:
# WARNING: saving figure to file figures/umapallcell_merge_class_new.pdf

# %%
adata = adata[adata.obs['Class_new'].isin (['Dopa', 'GABA', 'GABA-Glut', 'Glut', 'Non-neuron']),:]

# %%
adata
# Out:
# View of AnnData object with n_obs × n_vars = 22748 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'Neuron', 'Sample', 'leiden_res_1.00', 'leiden_res_1.20', 'Neuron_merge', 'Class_new'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Neuron_colors', 'Neuron_merge_colors', 'Sample_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'dendrogram_leiden_res_1.20', 'dendrogram_leiden_res_1.50', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'neighbors', 'pca', 'umap', 'Class_new_colors'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
Class_counts = adata.obs['Class_new'].value_counts()
print(Class_counts)
# Out:
# Class_new
# Non-neuron    11685
# GABA-Glut      6169
# Glut           2038
# GABA           1771
# Dopa           1085
# Name: count, dtype: int64

# %%
sc.pl.umap(
    adata,
    color=["Gpr37", "Gpr158"],
    legend_fontsize=8,vmax = 3.2,cmap='Spectral_r',save = 'allcell_merge_gpr37_158.pdf'
)
# Out:
# WARNING: saving figure to file figures/umapallcell_merge_gpr37_158.pdf

# %%
marker_gene_class_new = ['Gpr37','Gpr158','Slc17a6','Slc17a7','Slc17a8','Snap25','Slc32a1','Gad1','Gad2','Aldh1a1','Slc6a5','Chat','Slc6a3','Slc18a2','Th','Ddc','Slc6a4','Hdc']

# %%
sc.pl.dotplot(adata,marker_gene_class_new , 'Class_new',cmap='viridis_r',dendrogram=True,save = '_class_new.pdf')
# Out:
# WARNING: saving figure to file figures/dotplot__class_new.pdf

# %%
sc.pl.dotplot(adata,marker_gene_class_new , 'Class_new',cmap='Spectral_r',dendrogram=True,save = '_class_new_.pdf')
# Out:
# WARNING: saving figure to file figures/dotplot__class_new_.pdf

# %%
sc.pl.dotplot(adata,'Gpr158' , 'Class_new',cmap='Spectral_r',dendrogram=True,save = '_Gpr158_class_new.pdf')
# Out:
# WARNING: saving figure to file figures/dotplot__Gpr158_class_new.pdf

# %%
sc.pl.umap(
    adata,
    color="Class_new",
    legend_fontsize=8,palette= 'Set2'
)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/scanpy/plotting/_utils.py:465: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[value_to_plot + "_colors"] = colors_list

# %%
adata.write('VTA_allcell_merge_harmony.h5ad')

# %%
gaba = adata[adata.obs['Class_new'].isin (['GABA','GABA-Glut']),:]

# %%
gaba
# Out:
# View of AnnData object with n_obs × n_vars = 7940 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'Neuron', 'Sample', 'leiden_res_1.00', 'leiden_res_1.20', 'Neuron_merge', 'Class_new'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Neuron_colors', 'Neuron_merge_colors', 'Sample_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'dendrogram_leiden_res_1.20', 'dendrogram_leiden_res_1.50', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'neighbors', 'pca', 'umap', 'Class_new_colors'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(
    gaba,
    color="Class_new",
    legend_fontsize=8,palette= 'Set2'
)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/scanpy/plotting/_utils.py:465: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[value_to_plot + "_colors"] = colors_list

# %%
gaba.write('VTA_GABA_mix.h5ad')

# %%
adata=sc.read_h5ad('VTA_allcell_merge_harmony.h5ad')

# %%
sc.pl.dotplot(adata,['Il10ra','Il10rb'] , 'Class_new',cmap='Spectral_r',dendrogram=True)

# %%
sc.pl.umap(
    adata,
    color=['Class_new','Il10ra','Il10rb'],
    legend_fontsize=8,cmap='Spectral_r'
)

# %%
adata.obs
# Out:
#                           n_genes  percent_mito  n_counts  doublet_score  \
# AAACCCAAGACTGTTC-1-VTA_1     2892           0.0    6381.0       0.093149
# AAACCCACATACCGTA-1-VTA_1     1016           0.0    1703.0       0.046853
# AAACCCAGTAACGCGA-1-VTA_1     4184           0.0   10386.0       0.089820
# AAACCCAGTCACTAGT-1-VTA_1     3622           0.0    8986.0       0.032307
# AAACGAAAGAGCATTA-1-VTA_1     1570           0.0    2479.0       0.013114
# ...                           ...           ...       ...            ...
# TTTGTTGGTTCCCACT-1-VTA_2     2275           0.0    4429.0       0.039110
# TTTGTTGGTTTAGACC-1-VTA_2     1140           0.0    1956.0       0.012198
# TTTGTTGTCACGAACT-1-VTA_2     4517           0.0   13127.0       0.111898
# TTTGTTGTCAGAGCAG-1-VTA_2     1271           0.0    2199.0       0.019010
# TTTGTTGTCCTCTTTC-1-VTA_2     1334           0.0    2163.0       0.035227
#
#                           predicted_doublet      Neuron Sample  \
# AAACCCAAGACTGTTC-1-VTA_1              False      Neuron  VTA_1
# AAACCCACATACCGTA-1-VTA_1              False  Non-neuron  VTA_1
# AAACCCAGTAACGCGA-1-VTA_1              False      Neuron  VTA_1
# AAACCCAGTCACTAGT-1-VTA_1              False      Neuron  VTA_1
# AAACGAAAGAGCATTA-1-VTA_1              False      Neuron  VTA_1
# ...                                     ...         ...    ...
# TTTGTTGGTTCCCACT-1-VTA_2              False      Neuron  VTA_2
# TTTGTTGGTTTAGACC-1-VTA_2              False  Non-neuron  VTA_2
# TTTGTTGTCACGAACT-1-VTA_2              False      Neuron  VTA_2
# TTTGTTGTCAGAGCAG-1-VTA_2              False  Non-neuron  VTA_2
# TTTGTTGTCCTCTTTC-1-VTA_2              False      Neuron  VTA_2
#
#                          leiden_res_1.00 leiden_res_1.20 Neuron_merge  \
# AAACCCAAGACTGTTC-1-VTA_1               0               0       Neuron
# AAACCCACATACCGTA-1-VTA_1               1               2   Non-neuron
# AAACCCAGTAACGCGA-1-VTA_1               3               4       Neuron
# AAACCCAGTCACTAGT-1-VTA_1               4               5       Neuron
# AAACGAAAGAGCATTA-1-VTA_1               6              10       Neuron
# ...                                  ...             ...          ...
# TTTGTTGGTTCCCACT-1-VTA_2               4               5       Neuron
# TTTGTTGGTTTAGACC-1-VTA_2               7              11   Non-neuron
# TTTGTTGTCACGAACT-1-VTA_2               5               6       Neuron
# TTTGTTGTCAGAGCAG-1-VTA_2               2               3   Non-neuron
# TTTGTTGTCCTCTTTC-1-VTA_2              12              16       Neuron
#
#                            Class_new
# AAACCCAAGACTGTTC-1-VTA_1   GABA-Glut
# AAACCCACATACCGTA-1-VTA_1  Non-neuron
# AAACCCAGTAACGCGA-1-VTA_1        Glut
# AAACCCAGTCACTAGT-1-VTA_1   GABA-Glut
# AAACGAAAGAGCATTA-1-VTA_1        Dopa
# ...                              ...
# TTTGTTGGTTCCCACT-1-VTA_2        Glut
# TTTGTTGGTTTAGACC-1-VTA_2  Non-neuron
# TTTGTTGTCACGAACT-1-VTA_2   GABA-Glut
# TTTGTTGTCAGAGCAG-1-VTA_2  Non-neuron
# TTTGTTGTCCTCTTTC-1-VTA_2        Glut
#
# [22748 rows x 11 columns]

# %%
sc.pl.umap(
    adata,
    color=['Class_new','Tmem175','Tmem63a'],
    legend_fontsize=8,cmap='Spectral_r'
)

# %%
sc.pl.dotplot(adata,['Tmem175','Tmem63a'] , 'Class_new',cmap='Spectral_r',dendrogram=True)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_Class_new). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_Class_new']`

# %%
adata.obs
# Out:
#                           n_genes  percent_mito  n_counts  doublet_score  \
# AAACCCAAGACTGTTC-1-VTA_1     2892           0.0    6381.0       0.093149
# AAACCCACATACCGTA-1-VTA_1     1016           0.0    1703.0       0.046853
# AAACCCAGTAACGCGA-1-VTA_1     4184           0.0   10386.0       0.089820
# AAACCCAGTCACTAGT-1-VTA_1     3622           0.0    8986.0       0.032307
# AAACGAAAGAGCATTA-1-VTA_1     1570           0.0    2479.0       0.013114
# ...                           ...           ...       ...            ...
# TTTGTTGGTTCCCACT-1-VTA_2     2275           0.0    4429.0       0.039110
# TTTGTTGGTTTAGACC-1-VTA_2     1140           0.0    1956.0       0.012198
# TTTGTTGTCACGAACT-1-VTA_2     4517           0.0   13127.0       0.111898
# TTTGTTGTCAGAGCAG-1-VTA_2     1271           0.0    2199.0       0.019010
# TTTGTTGTCCTCTTTC-1-VTA_2     1334           0.0    2163.0       0.035227
#
#                           predicted_doublet      Neuron Sample  \
# AAACCCAAGACTGTTC-1-VTA_1              False      Neuron  VTA_1
# AAACCCACATACCGTA-1-VTA_1              False  Non-neuron  VTA_1
# AAACCCAGTAACGCGA-1-VTA_1              False      Neuron  VTA_1
# AAACCCAGTCACTAGT-1-VTA_1              False      Neuron  VTA_1
# AAACGAAAGAGCATTA-1-VTA_1              False      Neuron  VTA_1
# ...                                     ...         ...    ...
# TTTGTTGGTTCCCACT-1-VTA_2              False      Neuron  VTA_2
# TTTGTTGGTTTAGACC-1-VTA_2              False  Non-neuron  VTA_2
# TTTGTTGTCACGAACT-1-VTA_2              False      Neuron  VTA_2
# TTTGTTGTCAGAGCAG-1-VTA_2              False  Non-neuron  VTA_2
# TTTGTTGTCCTCTTTC-1-VTA_2              False      Neuron  VTA_2
#
#                          leiden_res_1.00 leiden_res_1.20 Neuron_merge  \
# AAACCCAAGACTGTTC-1-VTA_1               0               0       Neuron
# AAACCCACATACCGTA-1-VTA_1               1               2   Non-neuron
# AAACCCAGTAACGCGA-1-VTA_1               3               4       Neuron
# AAACCCAGTCACTAGT-1-VTA_1               4               5       Neuron
# AAACGAAAGAGCATTA-1-VTA_1               6              10       Neuron
# ...                                  ...             ...          ...
# TTTGTTGGTTCCCACT-1-VTA_2               4               5       Neuron
# TTTGTTGGTTTAGACC-1-VTA_2               7              11   Non-neuron
# TTTGTTGTCACGAACT-1-VTA_2               5               6       Neuron
# TTTGTTGTCAGAGCAG-1-VTA_2               2               3   Non-neuron
# TTTGTTGTCCTCTTTC-1-VTA_2              12              16       Neuron
#
#                            Class_new
# AAACCCAAGACTGTTC-1-VTA_1   GABA-Glut
# AAACCCACATACCGTA-1-VTA_1  Non-neuron
# AAACCCAGTAACGCGA-1-VTA_1        Glut
# AAACCCAGTCACTAGT-1-VTA_1   GABA-Glut
# AAACGAAAGAGCATTA-1-VTA_1        Dopa
# ...                              ...
# TTTGTTGGTTCCCACT-1-VTA_2        Glut
# TTTGTTGGTTTAGACC-1-VTA_2  Non-neuron
# TTTGTTGTCACGAACT-1-VTA_2   GABA-Glut
# TTTGTTGTCAGAGCAG-1-VTA_2  Non-neuron
# TTTGTTGTCCTCTTTC-1-VTA_2        Glut
#
# [22748 rows x 11 columns]

# %%
non_neuron = adata[adata.obs['Class_new'] == 'Non-neuron',:]

# %%
non_neuron.obs
# Out:
#                           n_genes  percent_mito  n_counts  doublet_score  \
# AAACCCACATACCGTA-1-VTA_1     1016           0.0    1703.0       0.046853
# AAACGAAAGGTAAGGA-1-VTA_1      902           0.0    1472.0       0.009311
# AAACGAACAACGGGTA-1-VTA_1      922           0.0    1269.0       0.003303
# AAACGAACAGTTAGGG-1-VTA_1      879           0.0    1509.0       0.057174
# AAACGAATCCCGTAAA-1-VTA_1     1069           0.0    1714.0       0.048170
# ...                           ...           ...       ...            ...
# TTTGTTGCATCGTCCT-1-VTA_2      821           0.0    1154.0       0.003590
# TTTGTTGGTCCTTGTC-1-VTA_2      777           0.0    1112.0       0.013088
# TTTGTTGGTCTTGAGT-1-VTA_2      829           0.0    1210.0       0.021540
# TTTGTTGGTTTAGACC-1-VTA_2     1140           0.0    1956.0       0.012198
# TTTGTTGTCAGAGCAG-1-VTA_2     1271           0.0    2199.0       0.019010
#
#                           predicted_doublet      Neuron Sample  \
# AAACCCACATACCGTA-1-VTA_1              False  Non-neuron  VTA_1
# AAACGAAAGGTAAGGA-1-VTA_1              False  Non-neuron  VTA_1
# AAACGAACAACGGGTA-1-VTA_1              False  Non-neuron  VTA_1
# AAACGAACAGTTAGGG-1-VTA_1              False  Non-neuron  VTA_1
# AAACGAATCCCGTAAA-1-VTA_1              False  Non-neuron  VTA_1
# ...                                     ...         ...    ...
# TTTGTTGCATCGTCCT-1-VTA_2              False  Non-neuron  VTA_2
# TTTGTTGGTCCTTGTC-1-VTA_2              False  Non-neuron  VTA_2
# TTTGTTGGTCTTGAGT-1-VTA_2              False  Non-neuron  VTA_2
# TTTGTTGGTTTAGACC-1-VTA_2              False  Non-neuron  VTA_2
# TTTGTTGTCAGAGCAG-1-VTA_2              False  Non-neuron  VTA_2
#
#                          leiden_res_1.00 leiden_res_1.20 Neuron_merge  \
# AAACCCACATACCGTA-1-VTA_1               1               2   Non-neuron
# AAACGAAAGGTAAGGA-1-VTA_1               7              11   Non-neuron
# AAACGAACAACGGGTA-1-VTA_1              10              14   Non-neuron
# AAACGAACAGTTAGGG-1-VTA_1               1               2   Non-neuron
# AAACGAATCCCGTAAA-1-VTA_1               1               2   Non-neuron
# ...                                  ...             ...          ...
# TTTGTTGCATCGTCCT-1-VTA_2              13              17   Non-neuron
# TTTGTTGGTCCTTGTC-1-VTA_2               7              11   Non-neuron
# TTTGTTGGTCTTGAGT-1-VTA_2               7              11   Non-neuron
# TTTGTTGGTTTAGACC-1-VTA_2               7              11   Non-neuron
# TTTGTTGTCAGAGCAG-1-VTA_2               2               3   Non-neuron
#
#                            Class_new
# AAACCCACATACCGTA-1-VTA_1  Non-neuron
# AAACGAAAGGTAAGGA-1-VTA_1  Non-neuron
# AAACGAACAACGGGTA-1-VTA_1  Non-neuron
# AAACGAACAGTTAGGG-1-VTA_1  Non-neuron
# AAACGAATCCCGTAAA-1-VTA_1  Non-neuron
# ...                              ...
# TTTGTTGCATCGTCCT-1-VTA_2  Non-neuron
# TTTGTTGGTCCTTGTC-1-VTA_2  Non-neuron
# TTTGTTGGTCTTGAGT-1-VTA_2  Non-neuron
# TTTGTTGGTTTAGACC-1-VTA_2  Non-neuron
# TTTGTTGTCAGAGCAG-1-VTA_2  Non-neuron
#
# [11685 rows x 11 columns]

# %%
sc.pl.dotplot(non_neuron,['Snap25','Cx3cr1','Aldh1l1','Gja1','Enpp6','Sox10','Pdgfra','Mog','Pecam1','Slc47a1','Slc6a13'] , 'leiden_res_1.20',cmap='Spectral_r')

# %%
set(non_neuron.obs['leiden_res_1.20'])
# Out:
# {'0',
#  '1',
#  '10',
#  '11',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '18',
#  '19',
#  '2',
#  '20',
#  '21',
#  '23',
#  '24',
#  '25',
#  '27',
#  '28',
#  '29',
#  '3',
#  '31',
#  '33',
#  '35',
#  '5',
#  '6',
#  '9'}

# %%
sc.pl.umap(
    non_neuron,
    color=['leiden_res_1.20'],
    legend_fontsize=8,cmap='Spectral_r',legend_loc="on data",
)

# %%
test = non_neuron[non_neuron.obs['leiden_res_1.20'] == '18',:]

# %%
test
# Out:
# View of AnnData object with n_obs × n_vars = 515 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'Neuron', 'Sample', 'leiden_res_1.00', 'leiden_res_1.20', 'Neuron_merge', 'Class_new'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Class_new_colors', 'Neuron_colors', 'Neuron_merge_colors', 'Sample_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'dendrogram_leiden_res_1.20', 'dendrogram_leiden_res_1.50', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'neighbors', 'pca', 'umap', 'dendrogram_Class_new'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
non_neuron = non_neuron[non_neuron.obs['leiden_res_1.20'].isin (['19','2','3','27','31','23','17','13','11','20','29','24','33','14','18']),:]

# %%
non_neuron
# Out:
# View of AnnData object with n_obs × n_vars = 11628 × 22948
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'doublet_score', 'predicted_doublet', 'Neuron', 'Sample', 'leiden_res_1.00', 'leiden_res_1.20', 'Neuron_merge', 'Class_new'
#     var: 'gene_ids', 'feature_types', 'n_cells-VTA_1', 'highly_variable-VTA_1', 'means-VTA_1', 'dispersions-VTA_1', 'dispersions_norm-VTA_1', 'n_cells-VTA_2', 'highly_variable-VTA_2', 'means-VTA_2', 'dispersions-VTA_2', 'dispersions_norm-VTA_2', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'Class_new_colors', 'Neuron_colors', 'Neuron_merge_colors', 'Sample_colors', 'dendrogram_leiden_res_0.50', 'dendrogram_leiden_res_0.80', 'dendrogram_leiden_res_1.00', 'dendrogram_leiden_res_1.20', 'dendrogram_leiden_res_1.50', 'hvg', 'leiden_res_0.50', 'leiden_res_0.50_colors', 'leiden_res_0.80', 'leiden_res_0.80_colors', 'leiden_res_1.00', 'leiden_res_1.00_colors', 'leiden_res_1.20', 'leiden_res_1.20_colors', 'leiden_res_1.50', 'leiden_res_1.50_colors', 'neighbors', 'pca', 'umap', 'dendrogram_Class_new'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(
    non_neuron,
    color=['leiden_res_1.20'],
    legend_fontsize=8,cmap='Spectral_r',legend_loc="on data",
)

# %%
sc.tl.dendrogram(non_neuron,'leiden_res_1.20')
# Out:
#     using 'X_pca' with n_pcs = 50
# Storing dendrogram info using `.uns['dendrogram_leiden_res_1.20']`
# /opt/anaconda3/lib/python3.11/site-packages/scanpy/tools/_dendrogram.py:190: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns[key_added] = dat

# %%
sc.pl.dotplot(non_neuron,['Snap25','Cx3cr1','Aldh1l1','Gja1','Enpp6','Sox10','Pdgfra','Mog','Pecam1','Slc47a1','Slc6a13'] , 'leiden_res_1.20',cmap='viridis_r',dendrogram=True)

# %%
Type = []
for i in range(non_neuron. shape[0]):
    if (int(non_neuron.obs['leiden_res_1.20'][i]) in (33,14,19)): Type.append('Microglia')
    elif (int(non_neuron.obs['leiden_res_1.20'][i]) in (11,31)): Type.append('Astrocytes')
    elif (int(non_neuron. obs['leiden_res_1.20'][i]) in (23,19,27,2,3)): Type.append('0ligodendrocytes')
    elif (int(non_neuron.obs['leiden_res_1.20'][i]) in (13,17)): Type.append('OPCs')
    elif (int(non_neuron.obs['leiden_res_1.20'][i]) == 24): Type.append(' Endothelia')
    elif (int(non_neuron.obs['leiden_res_1.20'][i]) == 20): Type.append('VLMCs')
    else: Type.append('Other')
non_neuron.obs['Type'] = Type
# Out:
# /var/folders/r4/hfj1yx3s3bd93mtgxzfwcfyc0000gn/T/ipykernel_28924/3359592947.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if (int(non_neuron.obs['leiden_res_1.20'][i]) in (33,14,19)): Type.append('Microglia')
# /var/folders/r4/hfj1yx3s3bd93mtgxzfwcfyc0000gn/T/ipykernel_28924/3359592947.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif (int(non_neuron.obs['leiden_res_1.20'][i]) in (11,31)): Type.append('Astrocytes')
# /var/folders/r4/hfj1yx3s3bd93mtgxzfwcfyc0000gn/T/ipykernel_28924/3359592947.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif (int(non_neuron. obs['leiden_res_1.20'][i]) in (23,19,27,2,3)): Type.append('0ligodendrocytes')
# /var/folders/r4/hfj1yx3s3bd93mtgxzfwcfyc0000gn/T/ipykernel_28924/3359592947.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif (int(non_neuron.obs['leiden_res_1.20'][i]) in (13,17)): Type.append('OPCs')
# /var/folders/r4/hfj1yx3s3bd93mtgxzfwcfyc0000gn/T/ipykernel_28924/3359592947.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif (int(non_neuron.obs['leiden_res_1.20'][i]) == 24): Type.append(' Endothelia')
# /var/folders/r4/hfj1yx3s3bd93mtgxzfwcfyc0000gn/T/ipykernel_28924/3359592947.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   elif (int(non_neuron.obs['leiden_res_1.20'][i]) == 20): Type.append('VLMCs')

# %%
sc.pl.umap(
    non_neuron,
    color=['Type','Tmem175','Tmem63a','Il10ra','Il10rb'],
    legend_fontsize=8,cmap='Spectral_r',
)

# %%
sc.pl.dotplot(non_neuron,['Tmem175','Tmem63a','Il10ra','Il10rb'] , 'Type',cmap='Spectral_r')
